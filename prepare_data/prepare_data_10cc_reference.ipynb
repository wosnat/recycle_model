# %%
import itertools
import sys, os

import numpy as np
import pandas as pd
from scipy.special import comb
from scipy import stats
import scipy.cluster.hierarchy as hac
from scipy.optimize import curve_fit

import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm

sns.set(rc={'figure.figsize':(15,8)})
sns.set_context('paper')
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_log_error
from statsmodels.tools.eval_measures import rmse

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('..')

# %%
from model_equations_separate_NC_sep_vmax import *

# %%
sns.set_context('talk')
sns.set_style('white')

# %%
# cdf = cdf1.loc[(cdf1.FL >= 0.2) & (cdf1.FCM >= 1e7) & cdf1.PRO.isin(['MED4'])]
cdf = pd.read_csv('fl_2_fcm_train_MED4.csv.gz')

# %%
X = cdf['FL']
y = cdf['FCM']
X.shape, y.shape
res = sm.OLS(y, sm.add_constant(X)).fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FCM   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     296.3
# Date:                Sun, 16 Jan 2022   Prob (F-statistic):           1.13e-26
# Time:                        14:54:54   Log-Likelihood:                -1282.8
# No. Observations:                  71   AIC:                             2570.
# Df Residuals:                      69   BIC:                             2574.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.369e+07   3.24e+06      4.228      0.000    7.23e+06    2.02e+07
# FL          2.613e+07   1.52e+06     17.214      0.000    2.31e+07    2.92e+07
# ==============================================================================
# Omnibus:                       15.708   Durbin-Watson:                   0.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.028
# Skew:                           0.916   Prob(JB):                     2.72e-05
# Kurtosis:                       4.936   Cond. No.                         3.86
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
dt = res.get_prediction(sm.add_constant(cdf['FL'])).summary_frame(alpha = 0.05)
y_pred = dt['mean']
cdf['ypred'] = y_pred
cdf['error'] = np.absolute(cdf['ypred'] - cdf['FCM'])
cdf['error'] = cdf['ypred'] - cdf['FCM']
cdf['relerror'] = cdf['error'] / cdf['FCM']

# %%
cdf.nlargest(10, 'relerror')
# Out:
#     Unnamed: 0     FL          FCM   PRO         day         ypred  \
# 49           2  0.626  11213350.13  MED4  100.000000  3.004984e+07
# 63         241  0.405  11810138.25  MED4   60.000000  2.427517e+07
# 62         240  0.444  12621428.57  MED4   60.000000  2.529423e+07
# 64         242  0.456  12794930.88  MED4   60.000000  2.560779e+07
# 60         226  0.489  13987327.19  MED4   60.000000  2.647007e+07
# 0           54  1.702  31400000.00  MED4    8.730000  5.816542e+07
# 43         240  0.696  17592880.98  MED4   24.672222  3.187892e+07
# 3           57  3.319  56109010.01  MED4    8.731250  1.004172e+08
# 48         290  0.618  16945494.99  MED4   29.629167  2.984080e+07
# 59         225  0.442  14562211.98  MED4   60.000000  2.524197e+07
#
#            error  relerror
# 49  1.883649e+07  1.679827
# 63  1.246503e+07  1.055452
# 62  1.267280e+07  1.004070
# 64  1.281286e+07  1.001401
# 60  1.248274e+07  0.892432
# 0   2.676542e+07  0.852402
# 43  1.428604e+07  0.812035
# 3   4.430818e+07  0.789680
# 48  1.289531e+07  0.760987
# 59  1.067976e+07  0.733388

# %%
sns.relplot(data=cdf, x=cdf['day'], y=cdf['relerror'], hue='FL')

# %%
sns.relplot(data=cdf, x=cdf['FL'], y=cdf['error'], hue='FCM')
plt.axhline(0, ls='--')

# %%
sns.relplot(data=cdf, x=cdf['FCM'], y=cdf['ypred'], hue='FL')
sns.lineplot(x=cdf['FCM'], y=cdf['FCM'],  color='grey', legend=False)
# Out:
# <AxesSubplot:xlabel='FCM', ylabel='ypred'>

# %%
sns.relplot(data=cdf, x=cdf['FL'], y=cdf['FCM'], hue='day')
sns.lineplot(x=cdf['FL'], y=cdf['ypred'],  color='grey', legend=False)
# Out:
# <AxesSubplot:xlabel='FL', ylabel='FCM'>

# %%
sns.relplot(data=cdf, x=cdf['FCM'], y=cdf['ypred'], hue='FL')
sns.lineplot(x=cdf['FCM'], y=cdf['FCM'],  color='grey', legend=False)
plt.yscale('log')
plt.xscale('log')

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  '10cc_fcm.csv.gz',
#  '10cc_fl.csv.gz',
#  'fl_2_fcm_train_MED4.csv.gz',
#  'prepare_data_10cc_reference.ipynb',
#  'refdf_10cc_1.csv.gz',
#  'refdf_10cc_10.csv.gz',
#  'refdf_10cc_11.csv.gz',
#  'refdf_10cc_12.csv.gz',
#  'refdf_10cc_13.csv.gz',
#  'refdf_10cc_14.csv.gz',
#  'refdf_10cc_15.csv.gz',
#  'refdf_10cc_16.csv.gz',
#  'refdf_10cc_17.csv.gz',
#  'refdf_10cc_18.csv.gz',
#  'refdf_10cc_19.csv.gz',
#  'refdf_10cc_2.csv.gz',
#  'refdf_10cc_20.csv.gz',
#  'refdf_10cc_21.csv.gz',
#  'refdf_10cc_22.csv.gz',
#  'refdf_10cc_23.csv.gz',
#  'refdf_10cc_24.csv.gz',
#  'refdf_10cc_25.csv.gz',
#  'refdf_10cc_26.csv.gz',
#  'refdf_10cc_27.csv.gz',
#  'refdf_10cc_28.csv.gz',
#  'refdf_10cc_29.csv.gz',
#  'refdf_10cc_3.csv.gz',
#  'refdf_10cc_30.csv.gz',
#  'refdf_10cc_4.csv.gz',
#  'refdf_10cc_5.csv.gz',
#  'refdf_10cc_6.csv.gz',
#  'refdf_10cc_7.csv.gz',
#  'refdf_10cc_8.csv.gz',
#  'refdf_10cc_9.csv.gz',
#  'ref_10cc.csv.gz']

# %%
fldf = pd.read_csv('10cc_fl.csv.gz',)
fcmdf = pd.read_csv('10cc_fcm.csv.gz',)

# %%
fldf
# Out:
#       Unnamed: 0  day Sample  id replicate  transfer  transfer day  \
# 0              0    0   10A0  10         A         0           0.0
# 1              6    0   10B0  10         B         0           0.0
# 2             12    0   10C0  10         C         0           0.0
# 3             18    0   11A0  11         A         0           0.0
# 4             24    0   11B0  11         B         0           0.0
# ...          ...  ...    ...  ..       ...       ...           ...
# 2437        7384  129    8B0   8         B         0           0.0
# 2438        7385  129    8C0   8         C         0           0.0
# 2439        7386  129    9A0   9         A         0           0.0
# 2440        7387  129    9B0   9         B         0           0.0
# 2441        7388  129    9C0   9         C         0           0.0
#
#      heterotroph                full name     FL             Group
# 0        HOT5_F3            Marinovum 5F3  0.061  Inhibited Viable
# 1        HOT5_F3            Marinovum 5F3  0.070  Inhibited Viable
# 2        HOT5_F3            Marinovum 5F3  0.108  Inhibited Viable
# 3        HOT5_C3          Roseovarius 5C3  0.080         Inhibited
# 4        HOT5_C3          Roseovarius 5C3  0.084         Inhibited
# ...          ...                      ...    ...               ...
# 2437     mit0604  Prochlorococcus mit0604    NaN               NaN
# 2438     mit0604  Prochlorococcus mit0604    NaN               NaN
# 2439        k-12                  E. coli  0.040  Inhibited Viable
# 2440        k-12                  E. coli  0.040  Inhibited Viable
# 2441        k-12                  E. coli  0.099  Inhibited Viable
#
# [2442 rows x 11 columns]

# %%
dt = res.get_prediction(sm.add_constant(fldf['FL'])).summary_frame(alpha = 0.05)
fldf['cells/ml'] = dt['mean']
fldf.loc[(fldf['FL'] <0.2) | (fldf['cells/ml'] < 1e6),  'cells/ml'] = np.NaN

# %%
axenic = ['Axenic']

group1 = ['A. macleodii 1A3', 'Pseudoalteromonas haloplanktis',]

group2 = ['Sulfitobacter pseudonitzschiae','Ruegeria pomeroyi', ]
group3 = [ #'Prochlorococcus mit0604',
    'E. coli',
         'Marinovum 5F3',
       ]
group4 = ['Marinobacter adhaerens HP15',
       'Phaeobacter gallaeciensis', 'Roseovarius 5C3']

horder =  group1 + group2 + group3 + group4 + ['Axenic']
# ['Axenic', 'HOT1A3',  'CIP',  'nitzsch', 'mit0604',
#           'DSS-3','k-12','HOT5_F3', 'HOT5_C3'
#           'HP15', 'Pgall',
#          ]
gorder = ['Sustained', 'Strong', 'Inhibited Viable', 'Inhibited',   'Axenic',  ]
hpalette1 = sns.color_palette("Dark2", n_colors=len(group1)).as_hex() 
hpalette2 = sns.color_palette("terrain", n_colors=len(group2)).as_hex()  
hpalette3 = sns.color_palette("winter", n_colors=len(group3)+1).as_hex()[1:]  
hpalette4 = sns.color_palette("spring", n_colors=len(group4)).as_hex()

transfer_days = [20, 42, 60, 81, 129]
transfer_days = [42, 60, 81, 129]


hpalette =  hpalette1 + hpalette2 + hpalette3 + hpalette4 + ['black']
gpalette = [ hpalette[7], hpalette[1], hpalette[3], hpalette[5], hpalette[9],]
sns.color_palette(hpalette)
# Out:
# [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667), (0.85098039215
# 68627, 0.37254901960784315, 0.00784313725490196), (0.3333333333333333, 0.86666
# 66666666667, 0.4666666666666667), (0.6666666666666666, 0.5725490196078431, 0.4
# 196078431372549), (0.0, 0.5019607843137255, 0.7490196078431373), (0.0, 0.75294
# 11764705882, 0.6235294117647059), (1.0, 0.25098039215686274, 0.749019607843137
# 3), (1.0, 0.5019607843137255, 0.4980392156862745), (1.0, 0.7529411764705882, 0
# .24705882352941178), (0.0, 0.0, 0.0)]

# %%
g = sns.relplot(
    data=fldf, x='day', y='cells/ml',
    kind='line', units='replicate', estimator=None,
    col='full name', hue='full name', col_order=horder,
    hue_order=horder, palette=hpalette, col_wrap=5, 
    style='transfer', markers=True, dashes=False,

).set(yscale='log',xlim=(0,140)).set_titles(row_template = '', col_template = '{col_name}')

for ax, name in zip(g.axes.flat, horder):
    sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['med4 (FCM)'])],
                    x='transfer day', y='value', ax=ax, legend=False,
                    c=['red'], s=100, marker='X',
                   )
    sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['het (FCM)'])],
                    x='transfer day', y='value', ax=ax, legend=False,
                    c=['black'], s=100, marker='P',
                   )

    ax.axhline(1e7, ls='--')

# %%
g = sns.relplot(
    data=fldf, x='day', y='cells/ml',
    kind='line', units='replicate', estimator=None,
    col='full name', hue='full name', col_order=horder,
    hue_order=horder, palette=hpalette, col_wrap=5, 
    style='transfer', markers=True, dashes=False,

).set(#yscale='log',
    xlim=(0,140)).set_titles(row_template = '', col_template = '{col_name}')

for ax, name in zip(g.axes.flat, horder):
    sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['med4 (FCM)'])],
                    x='transfer day', y='value', ax=ax, legend=False,
                    c=['red'], s=100, marker='X',
                   )
    sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['het (FCM)'])],
                    x='transfer day', y='value', ax=ax, legend=False,
                    c=['black'], s=100, marker='P',
                   )

    ax.axhline(0, ls='--')

# %%
fldf.head()
# Out:
#    Unnamed: 0  day Sample  id replicate  transfer  transfer day heterotroph  \
# 0           0    0   10A0  10         A         0           0.0     HOT5_F3
# 1           6    0   10B0  10         B         0           0.0     HOT5_F3
# 2          12    0   10C0  10         C         0           0.0     HOT5_F3
# 3          18    0   11A0  11         A         0           0.0     HOT5_C3
# 4          24    0   11B0  11         B         0           0.0     HOT5_C3
#
#          full name     FL             Group  cells/ml
# 0    Marinovum 5F3  0.061  Inhibited Viable       NaN
# 1    Marinovum 5F3  0.070  Inhibited Viable       NaN
# 2    Marinovum 5F3  0.108  Inhibited Viable       NaN
# 3  Roseovarius 5C3  0.080         Inhibited       NaN
# 4  Roseovarius 5C3  0.084         Inhibited       NaN

# %%
fcmdf.tail()
# Out:
#      Unnamed: 0 tube Sample  id replicate  transfer heterotroph  \
# 268          25  NaN     7b   7         B       5.0     nitzsch
# 269          26  NaN     7c   7         C       5.0     nitzsch
# 270          27  NaN     9a   9         A       5.0        k-12
# 271          28  NaN     9b   9         B       5.0        k-12
# 272          29  NaN     9c   9         C       5.0        k-12
#
#                           full name                 date  transfer day  \
# 268  Sulfitobacter pseudonitzschiae  2021-08-29 15:49:00    128.984028
# 269  Sulfitobacter pseudonitzschiae  2021-08-29 15:49:00    128.984028
# 270                         E. coli  2021-08-29 15:49:00    128.984028
# 271                         E. coli  2021-08-29 15:49:00    128.984028
# 272                         E. coli  2021-08-29 15:49:00    128.984028
#
#       variable      value transfer_success
# 268  het (MPN)  5000000.0              NaN
# 269  het (MPN)   500000.0              NaN
# 270  het (MPN)        0.0              NaN
# 271  het (MPN)        0.0              NaN
# 272  het (MPN)        0.0              NaN

# %%
fldf.columns
# Out:
# Index(['Unnamed: 0', 'day', 'Sample', 'id', 'replicate', 'transfer',
#        'transfer day', 'heterotroph', 'full name', 'FL', 'Group', 'cells/ml'],
#       dtype='object')

# %%
fcmdf.columns
# Out:
# Index(['Unnamed: 0', 'tube', 'Sample', 'id', 'replicate', 'transfer',
#        'heterotroph', 'full name', 'date', 'transfer day', 'variable', 'value',
#        'transfer_success'],
#       dtype='object')

# %%
fcmdf['day'] = fcmdf['transfer day']

# %%
fcmpdf = fcmdf.loc[fcmdf.variable.isin(['het (FCM)', 'med4 (FCM)'])].pivot(
    index=['Sample', 'id', 'replicate','heterotroph', 'full name','day'],
    columns=['variable'],
    values=['value']
).reset_index().rename(columns={
    ('value', 'het (FCM)') : 'cc het',
    ('value', 'med4 (FCM)') : 'cc med4',
})

fcmpdf.columns = ['Sample',
                     'id',
              'replicate',
            'heterotroph',
              'full name',
                    'day',
              'het (FCM)',
             'med4 (FCM)']
fcmpdf
# Out:
#     Sample  id replicate heterotroph      full name         day     het (FCM)  \
# 0     10A1  10         A     HOT5_F3  Marinovum 5F3   19.817361  2.524283e+07
# 1     10A2  10         A     HOT5_F3  Marinovum 5F3   41.843750  2.183200e+07
# 2     10A3  10         A     HOT5_F3  Marinovum 5F3   59.923611  1.030743e+07
# 3     10A4  10         A     HOT5_F3  Marinovum 5F3   80.893056  1.626928e+07
# 4     10A5  10         A     HOT5_F3  Marinovum 5F3  128.984028  1.973477e+07
# ..     ...  ..       ...         ...            ...         ...           ...
# 139    9C1   9         C        k-12        E. coli   19.817361  2.420268e+07
# 140    9C2   9         C        k-12        E. coli   41.843750  1.961925e+07
# 141    9C3   9         C        k-12        E. coli   59.923611  1.893308e+07
# 142    9C4   9         C        k-12        E. coli   80.893056  3.268683e+06
# 143    9C5   9         C        k-12        E. coli  128.984028           NaN
#
#        med4 (FCM)
# 0    3.315642e+05
# 1    9.814324e+04
# 2             NaN
# 3    2.172097e+04
# 4    1.561574e+04
# ..            ...
# 139  8.151108e+06
# 140  3.567639e+05
# 141  3.600517e+05
# 142  1.859649e+05
# 143  1.472393e+03
#
# [144 rows x 8 columns]

# %%
fcmpdf.columns, fldf.columns
# Out:
# (Index(['Sample', 'id', 'replicate', 'heterotroph', 'full name', 'day',
#         'het (FCM)', 'med4 (FCM)'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'day', 'Sample', 'id', 'replicate', 'transfer',
#         'transfer day', 'heterotroph', 'full name', 'FL', 'Group', 'cells/ml'],
#        dtype='object'))

# %%
fcmpdf['cc het'] = fcmpdf['het (FCM)']* 1000
fcmpdf['cc med4'] = fcmpdf['med4 (FCM)']* 1000
fldf  ['cc med4'] = fldf['cells/ml']* 1000
fldf['cc het'] = np.NaN

# %%
columns = ['Sample', 'id', 'replicate', 'heterotroph', 'full name', 'day',
         'cc het', 'cc med4']

df = pd.concat([fcmpdf[columns], fldf[columns]])

# %%
df.head()
# Out:
#   Sample  id replicate heterotroph      full name         day        cc het  \
# 0   10A1  10         A     HOT5_F3  Marinovum 5F3   19.817361  2.524283e+10
# 1   10A2  10         A     HOT5_F3  Marinovum 5F3   41.843750  2.183200e+10
# 2   10A3  10         A     HOT5_F3  Marinovum 5F3   59.923611  1.030743e+10
# 3   10A4  10         A     HOT5_F3  Marinovum 5F3   80.893056  1.626928e+10
# 4   10A5  10         A     HOT5_F3  Marinovum 5F3  128.984028  1.973477e+10
#
#         cc med4
# 0  3.315642e+08
# 1  9.814324e+07
# 2           NaN
# 3  2.172097e+07
# 4  1.561574e+07

# %%
df['t'] = np.round(df['day']* seconds_in_day, decimals=0)

df['cc Bh[N]'] = df['cc het']* Qh
df['cc Bp[N]'] = df['cc med4']* Qp

df['cc Bh[C]'] = df['cc Bh[N]']* R_H
df['cc Bp[C]'] = df['cc Bp[N]']* R_P

# %%
df.Sample = df['id'].astype(str) + df['replicate']

# %%
df.columns
# Out:
# Index(['Sample', 'id', 'replicate', 'heterotroph', 'full name', 'day',
#        'cc het', 'cc med4', 't', 'cc Bh[N]', 'cc Bp[N]', 'cc Bh[C]',
#        'cc Bp[C]'],
#       dtype='object')

# %%
g = sns.relplot(
    data=df.melt(
        id_vars=['Sample', 'id', 'replicate', 'heterotroph', 'full name', 'day',], 
        value_vars=['cc Bh[N]', 'cc Bp[N]'],),
                 
    x='day', y='value',
    #kind='line', units='replicate', estimator=None,
    col='full name', hue='full name', col_order=horder,
    hue_order=horder, palette=hpalette, col_wrap=5, 
    style='variable', markers=True, dashes=False, s=100,

#)#.set(#yscale='log',
#    xlim=(0,140)
).set_titles(row_template = '', col_template = '{col_name}').set(yscale='log',)

# for ax, name in zip(g.axes.flat, horder):
#     sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['med4 (FCM)'])],
#                     x='transfer day', y='value', ax=ax, legend=False,
#                     c=['red'], s=100, marker='X',
#                    )
#     sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['het (FCM)'])],
#                     x='transfer day', y='value', ax=ax, legend=False,
#                     c=['black'], s=100, marker='P',
#                    )

#     ax.axhline(0, ls='--')

# %%
g = sns.relplot(
    data=df.melt(
        id_vars=['Sample', 'id', 'replicate', 'heterotroph', 'full name', 'day',], 
        value_vars=['cc Bh[N]', 'cc Bp[N]'],),
                 
    x='day', y='value',
    #kind='line', units='replicate', estimator=None,
    col='full name', hue='full name', col_order=horder,
    hue_order=horder, palette=hpalette, col_wrap=5, 
    style='variable', markers=True, dashes=False, s=100,

#)#.set(#yscale='log',
#    xlim=(0,140)
).set_titles(row_template = '', col_template = '{col_name}')#.set(yscale='log',)

# for ax, name in zip(g.axes.flat, horder):
#     sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['med4 (FCM)'])],
#                     x='transfer day', y='value', ax=ax, legend=False,
#                     c=['red'], s=100, marker='X',
#                    )
#     sns.scatterplot(data=fcmdf.loc[fcmdf['full name'].isin([name]) & fcmdf.variable.isin(['het (FCM)'])],
#                     x='transfer day', y='value', ax=ax, legend=False,
#                     c=['black'], s=100, marker='P',
#                    )

#     ax.axhline(0, ls='--')

# %%
df.Sample.unique()
# Out:
# array(['10A', '10B', '10C', '11A', '11B', '11C', '1A', '1B', '1C', '2A',
#        '2B', '2C', '3A', '3B', '3C', '4A', '4B', '4C', '5A', '5B', '5C',
#        '6A', '6B', '6C', '7A', '7B', '7C', '9A', '9B', '9C', '8A', '8B',
#        '8C'], dtype=object)

# %%
df.dropna(how='all', subset=['cc Bh[N]', 'cc Bp[N]']).groupby(['full name', 'Sample'])[['cc Bh[N]', 'cc Bp[N]']].nunique()
# Out:
#                                        cc Bh[N]  cc Bp[N]
# full name                      Sample
# A. macleodii 1A3               2A             5        62
#                                2B             5        59
#                                2C             5        64
# Axenic                         1A             0        25
#                                1B             0        21
#                                1C             0        21
# E. coli                        9A             4        12
#                                9B             4        12
#                                9C             4        25
# Marinobacter adhaerens HP15    3A             5         2
#                                3B             5         2
#                                3C             5         2
# Marinovum 5F3                  10A            5         7
#                                10B            5         5
#                                10C            5        19
# Phaeobacter gallaeciensis      4A             5         2
#                                4B             5         2
#                                4C             5         2
# Prochlorococcus mit0604        8A             0        13
#                                8B             0        14
#                                8C             0        13
# Pseudoalteromonas haloplanktis 5A             5        41
#                                5B             5        49
#                                5C             4        51
# Roseovarius 5C3                11A            5        16
#                                11B            5         6
#                                11C            5         3
# Ruegeria pomeroyi              6A             4        20
#                                6B             5        17
#                                6C             5        20
# Sulfitobacter pseudonitzschiae 7A             5        66
#                                7B             5        37
#                                7C             5        44

# %%
for i,s in enumerate(df.loc[~df['full name'].isin(['Axenic'])].Sample.unique()):
    print(i, s, f'refdf_{i+1}.csv.gz')
    df.loc[df.Sample.isin([s])].dropna(how='all', subset=['cc Bh[N]', 'cc Bp[N]']
                                         ).sort_values('t').to_csv(f'refdf_10cc_{i+1}.csv.gz')
# Out:
# 0 10A refdf_1.csv.gz
# 1 10B refdf_2.csv.gz
# 2 10C refdf_3.csv.gz
# 3 11A refdf_4.csv.gz
# 4 11B refdf_5.csv.gz
# 5 11C refdf_6.csv.gz
# 6 2A refdf_7.csv.gz
# 7 2B refdf_8.csv.gz
# 8 2C refdf_9.csv.gz
# 9 3A refdf_10.csv.gz
# 10 3B refdf_11.csv.gz
# 11 3C refdf_12.csv.gz
# 12 4A refdf_13.csv.gz
# 13 4B refdf_14.csv.gz
# 14 4C refdf_15.csv.gz
# 15 5A refdf_16.csv.gz
# 16 5B refdf_17.csv.gz
# 17 5C refdf_18.csv.gz
# 18 6A refdf_19.csv.gz
# 19 6B refdf_20.csv.gz
# 20 6C refdf_21.csv.gz
# 21 7A refdf_22.csv.gz
# 22 7B refdf_23.csv.gz
# 23 7C refdf_24.csv.gz
# 24 9A refdf_25.csv.gz
# 25 9B refdf_26.csv.gz
# 26 9C refdf_27.csv.gz
# 27 8A refdf_28.csv.gz
# 28 8B refdf_29.csv.gz
# 29 8C refdf_30.csv.gz

# %%
    df.loc[df.Sample.isin(['5A'])].dropna(how='all', subset=['cc Bh[N]', 'cc Bp[N]']).sort_values('t')
# Out:
#      Sample  id replicate heterotroph                       full name  \
# 150      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 183      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 216      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 249      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 282      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 315      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 348      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 381      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 414      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 447      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 480      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 513      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 546      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 579      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 612      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 85       5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 645      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 678      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 711      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 744      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 777      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 810      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 843      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 876      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 909      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 942      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 975      5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1008     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1041     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1074     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1107     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1140     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1173     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 86       5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1206     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1239     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1272     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1305     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 1338     5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 87       5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 88       5A   5         A         CIP  Pseudoalteromonas haloplanktis
# 89       5A   5         A         CIP  Pseudoalteromonas haloplanktis
#
#              day        cc het       cc med4           t    cc Bh[N]  \
# 150     4.000000           NaN  1.998990e+10    345600.0         NaN
# 183     5.000000           NaN  2.155768e+10    432000.0         NaN
# 216     6.000000           NaN  2.631329e+10    518400.0         NaN
# 249     7.000000           NaN  3.228829e+10    604800.0         NaN
# 282     8.000000           NaN  3.237538e+10    691200.0         NaN
# 315     9.000000           NaN  2.521584e+10    777600.0         NaN
# 348    10.000000           NaN  2.528552e+10    864000.0         NaN
# 381    11.000000           NaN  2.486744e+10    950400.0         NaN
# 414    12.000000           NaN  2.519842e+10   1036800.0         NaN
# 447    13.000000           NaN  3.129536e+10   1123200.0         NaN
# 480    14.000000           NaN  3.294153e+10   1209600.0         NaN
# 513    16.000000           NaN  3.161762e+10   1382400.0         NaN
# 546    17.000000           NaN  2.684459e+10   1468800.0         NaN
# 579    18.000000           NaN  3.061598e+10   1555200.0         NaN
# 612    19.000000           NaN  3.018049e+10   1641600.0         NaN
# 85     19.817361  5.068515e+10  1.370965e+10   1712220.0  446.029318
# 645    20.000000           NaN  3.286314e+10   1728000.0         NaN
# 678    21.000000           NaN  3.361219e+10   1814400.0         NaN
# 711    22.000000           NaN  3.130407e+10   1900800.0         NaN
# 744    24.000000           NaN  3.064211e+10   2073600.0         NaN
# 777    26.000000           NaN  4.031011e+10   2246400.0         NaN
# 810    27.000000           NaN  3.908201e+10   2332800.0         NaN
# 843    28.000000           NaN  3.776682e+10   2419200.0         NaN
# 876    30.000000           NaN  2.780268e+10   2592000.0         NaN
# 909    31.000000           NaN  3.770585e+10   2678400.0         NaN
# 942    32.000000           NaN  4.050173e+10   2764800.0         NaN
# 975    33.000000           NaN  3.822844e+10   2851200.0         NaN
# 1008   34.000000           NaN  3.848103e+10   2937600.0         NaN
# 1041   35.000000           NaN  3.710486e+10   3024000.0         NaN
# 1074   37.000000           NaN  2.856044e+10   3196800.0         NaN
# 1107   38.000000           NaN  3.064211e+10   3283200.0         NaN
# 1140   40.000000           NaN  3.034598e+10   3456000.0         NaN
# 1173   41.000000           NaN  2.929208e+10   3542400.0         NaN
# 86     41.843750  7.017307e+10  5.956233e+09   3615300.0  617.523005
# 1206   42.000000           NaN  2.999758e+10   3628800.0         NaN
# 1239   45.000000           NaN  2.944886e+10   3888000.0         NaN
# 1272   47.000000           NaN  2.197575e+10   4060800.0         NaN
# 1305   48.000000           NaN  2.095669e+10   4147200.0         NaN
# 1338   49.000000           NaN  1.907535e+10   4233600.0         NaN
# 87     59.923611  5.557724e+10  1.292178e+09   5177400.0  489.079730
# 88     80.893056  2.373055e+10  1.948649e+09   6989160.0  208.828837
# 89    128.984028  2.172840e+09  1.355499e+08  11144220.0   19.120988
#
#        cc Bp[N]     cc Bh[C]    cc Bp[C]
# 150   21.988885          NaN  145.676360
# 183   23.713446          NaN  157.101582
# 216   28.944617          NaN  191.758090
# 249   35.517114          NaN  235.300882
# 282   35.612923          NaN  235.935616
# 315   27.737424          NaN  183.760434
# 348   27.814071          NaN  184.268222
# 381   27.354188          NaN  181.221496
# 414   27.718262          NaN  183.633488
# 447   34.424892          NaN  228.064908
# 480   36.235682          NaN  240.061391
# 513   34.779385          NaN  230.413425
# 546   29.529052          NaN  195.629971
# 579   33.677582          NaN  223.113978
# 612   33.198537          NaN  219.940305
# 85    15.080612  2954.944232   99.909054
# 645   36.149454          NaN  239.490130
# 678   36.973411          NaN  244.948847
# 711   34.434473          NaN  228.128381
# 744   33.706324          NaN  223.304398
# 777   44.341122          NaN  293.759936
# 810   42.990216          NaN  284.810178
# 843   41.543500          NaN  275.225686
# 876   30.582951          NaN  202.612051
# 909   41.476434          NaN  274.781372
# 942   44.551902          NaN  295.156352
# 975   42.051287          NaN  278.589779
# 1008  42.329134          NaN  280.430510
# 1041  40.815351          NaN  270.401703
# 1074  31.416489          NaN  208.134242
# 1107  33.706324          NaN  223.304398
# 1140  33.380574          NaN  221.146301
# 1173  32.221285          NaN  213.466012
# 86     6.551857  4091.089911   43.406051
# 1206  32.997338          NaN  218.607362
# 1239  32.393741          NaN  214.608535
# 1272  24.173330          NaN  160.148308
# 1305  23.052364          NaN  152.721914
# 1338  20.982890          NaN  139.011647
# 87     1.421396  3240.153211    9.416750
# 88     2.143514  1383.491044   14.200783
# 89     0.149105   126.676543    0.987820

# %%
df.to_csv(f'ref_10cc.csv.gz')

# %%
fcmdf.loc[fcmdf.variable.isin(['het (FCM)']) & fcmdf['full name'].isin(['Sulfitobacter pseudonitzschiae'])].sort_values('value')
# Out:
#      Unnamed: 0                                          tube Sample  id  \
# 189         873       specimen_1_CC_001+sybr_Tube_030_058.fcs    7C3   7
# 219         908  specimen_2_CC+sybr_1,3a,100_Tube_007_198.fcs    7C4   7
# 217         906  specimen_2_CC+sybr_1,3a,100_Tube_005_196.fcs    7B4   7
# 240         936           specimen_3_CC+sybr_Tube_030_189.fcs    7C5   7
# 215         904  specimen_2_CC+sybr_1,3a,100_Tube_003_194.fcs    7A4   7
# 232         926           specimen_3_CC+sybr_Tube_019_178.fcs    7B5   7
# 172         855       specimen_1_CC_001+sybr_Tube_008_038.fcs    7A3   7
# 151         832           specimen_2_CC+sybr_Tube_023_114.fcs    7B2   7
# 224         916           specimen_3_CC+sybr_Tube_008_167.fcs    7A5   7
# 125         805       specimen_1_CC_001+sybr_Tube_023_052.fcs    7B1   7
# 124         804       specimen_1_CC_001+sybr_Tube_022_051.fcs    7A1   7
# 152         833           specimen_2_CC+sybr_Tube_024_115.fcs    7C2   7
# 150         831           specimen_2_CC+sybr_Tube_022_113.fcs    7A2   7
# 181         864       specimen_1_CC_001+sybr_Tube_019_048.fcs    7B3   7
# 166         847           specimen_2_CC+sybr_Tube_039_129.fcs    7C1   7
#
#     replicate  transfer heterotroph                       full name  \
# 189         C       3.0     nitzsch  Sulfitobacter pseudonitzschiae
# 219         C       4.0     nitzsch  Sulfitobacter pseudonitzschiae
# 217         B       4.0     nitzsch  Sulfitobacter pseudonitzschiae
# 240         C       5.0     nitzsch  Sulfitobacter pseudonitzschiae
# 215         A       4.0     nitzsch  Sulfitobacter pseudonitzschiae
# 232         B       5.0     nitzsch  Sulfitobacter pseudonitzschiae
# 172         A       3.0     nitzsch  Sulfitobacter pseudonitzschiae
# 151         B       2.0     nitzsch  Sulfitobacter pseudonitzschiae
# 224         A       5.0     nitzsch  Sulfitobacter pseudonitzschiae
# 125         B       1.0     nitzsch  Sulfitobacter pseudonitzschiae
# 124         A       1.0     nitzsch  Sulfitobacter pseudonitzschiae
# 152         C       2.0     nitzsch  Sulfitobacter pseudonitzschiae
# 150         A       2.0     nitzsch  Sulfitobacter pseudonitzschiae
# 181         B       3.0     nitzsch  Sulfitobacter pseudonitzschiae
# 166         C       1.0     nitzsch  Sulfitobacter pseudonitzschiae
#
#                     date  transfer day   variable         value  \
# 189  2021-06-21 14:22:00     59.923611  het (FCM)  1.062295e+06
# 219  2021-07-12 13:38:00     80.893056  het (FCM)  1.644497e+06
# 217  2021-07-12 13:38:00     80.893056  het (FCM)  6.235946e+06
# 240  2021-08-29 15:49:00    128.984028  het (FCM)  7.958582e+06
# 215  2021-07-12 13:38:00     80.893056  het (FCM)  1.347268e+07
# 232  2021-08-29 15:49:00    128.984028  het (FCM)  4.074632e+07
# 172  2021-06-21 14:22:00     59.923611  het (FCM)  9.455738e+07
# 151  2021-06-03 12:27:00     41.843750  het (FCM)  1.352149e+08
# 224  2021-08-29 15:49:00    128.984028  het (FCM)  1.371350e+08
# 125  2021-05-12 11:49:00     19.817361  het (FCM)  1.372224e+08
# 124  2021-05-12 11:49:00     19.817361  het (FCM)  1.373276e+08
# 152  2021-06-03 12:27:00     41.843750  het (FCM)  1.407826e+08
# 150  2021-06-03 12:27:00     41.843750  het (FCM)  1.422744e+08
# 181  2021-06-21 14:22:00     59.923611  het (FCM)  1.603672e+08
# 166  2021-05-12 11:49:00     19.817361  het (FCM)  3.461714e+08
#
#     transfer_success         day
# 189             True   59.923611
# 219             True   80.893056
# 217             True   80.893056
# 240            False  128.984028
# 215             True   80.893056
# 232             True  128.984028
# 172             True   59.923611
# 151             True   41.843750
# 224             True  128.984028
# 125             True   19.817361
# 124             True   19.817361
# 152             True   41.843750
# 150             True   41.843750
# 181             True   59.923611
# 166             True   19.817361
