# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import seaborn_figure_settings

# %%
import os
save_dpath = os.path.join('../notebooks/figures/', 'Het_curves')
os.makedirs(save_dpath,exist_ok=True)

# %%
import sys
sys.path.append('..')
from model_equations_separate_NC_store_numba import *

# %%
morder = ['MIXOTROPH','OVERFLOW','EXOENZYME',   'ROS',]#'MIN', ]
media_order = ['lowN', 'pro99']
mpalette = [ '#426b69', '#9b7874', '#b191ff', '#84dcc6',]# '#d6d4a0',]
sns.color_palette(mpalette)
# Out:
# [(0.25882352941176473, 0.4196078431372549, 0.4117647058823529),
#  (0.6078431372549019, 0.47058823529411764, 0.4549019607843137),
#  (0.6941176470588235, 0.5686274509803921, 1.0),
#  (0.5176470588235295, 0.8627450980392157, 0.7764705882352941)]

# %%
gorder = [ 'Strong', 'Sustained', 'Inhibited', 'Weak', 'Neutral',   'Other']
gpalette = sns.color_palette('Set2', n_colors=4).as_hex() + ['black', 'lightgrey']
gpalette = ['#882255', '#CC6677', '#332288', 
             '#44AA99','#88CCEE',
            '#D0CFCA',  ]

sns.color_palette(gpalette)
# Out:
# [(0.5333333333333333, 0.13333333333333333, 0.3333333333333333),
#  (0.8, 0.4, 0.4666666666666667),
#  (0.2, 0.13333333333333333, 0.5333333333333333),
#  (0.26666666666666666, 0.6666666666666666, 0.6),
#  (0.5333333333333333, 0.8, 0.9333333333333333),
#  (0.8156862745098039, 0.8117647058823529, 0.792156862745098)]

# %%
HCOLOR = '#ffc58f'
HCOLOR_light = '#ffd2a9'
PCOLOR = '#99cc99'
PCOLOR_light = '#aad5aa'

DONCOLOR = '#7285b7'
RDONCOLOR = 'black' #'#00334D'
DINCOLOR = '#bbdaff' #'#000066'

DOCCOLOR = '#cc6666'
RDOCCOLOR = 'black' #'#00334D'
DICCOLOR = '#ff9da4' #'#000066'

SHCOLOR = '#ffa98f'
SPCOLOR = '#326232'


ccnpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light, SPCOLOR, SHCOLOR,DONCOLOR, RDONCOLOR, DINCOLOR]
ccnorder = ['Bp', 'Np', 'Bh','Nh',  'ABp', 'ABh', 'DON', 'RDON', 'DIN', ]
cccpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
cccorder = ['Bp[C]', 'Cp', 'Bh[C]', 'Ch', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
ccxpalette = [PCOLOR, HCOLOR]
ccxorder = ['Xp', 'Xh']
hnpalette = [ HCOLOR_light, SPCOLOR, SHCOLOR, DONCOLOR, RDONCOLOR, DINCOLOR]
hnorder = [ 'Bh', 'ABp', 'ABh', 'DON', 'RDON', 'DIN']
hcpalette = [ HCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
hcorder = [ 'Bh[C]', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
pnpalette = [ PCOLOR_light, SPCOLOR, SHCOLOR, DONCOLOR, RDONCOLOR, DINCOLOR]
pnorder = [ 'Bp', 'ABp', 'ABh', 'DON', 'RDON', 'DIN']
pcpalette = [ PCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
pcorder = [ 'Bp[C]', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
sns.color_palette(ccnpalette + cccpalette, )
#
# Out:
# [(0.6, 0.8, 0.6),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (1.0, 0.8235294117647058, 0.6627450980392157),
#  (0.19607843137254902, 0.3843137254901961, 0.19607843137254902),
#  (1.0, 0.6627450980392157, 0.5607843137254902),
#  (0.4470588235294118, 0.5215686274509804, 0.7176470588235294),
#  (0.0, 0.0, 0.0),
#  (0.7333333333333333, 0.8549019607843137, 1.0),
#  (0.6, 0.8, 0.6),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (1.0, 0.8235294117647058, 0.6627450980392157),
#  (0.19607843137254902, 0.3843137254901961, 0.19607843137254902),
#  (1.0, 0.6627450980392157, 0.5607843137254902),
#  (0.8, 0.4, 0.4),
#  (0.0, 0.0, 0.0),
#  (1.0, 0.615686274509804, 0.6431372549019608)]

# %%
ccnorder = ['Bp', 'Np','Bh',  'Nh', 'DIN','DON',  'RDON', ]
ccnpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light,DINCOLOR, DONCOLOR, RDONCOLOR, ]

#Hex Codes: #262842, #293961, #2C497F, #8897BD, #E3E4FA
#Hex Codes: #49593C, #945C39, #DF5F35, #EF9E84, #FFE3D1
#Hex Codes: #5E1525, #C74F29, #E99E46, #B6C38D, #828144
ccnpalette = ['#2F6755', '#98A69A', '#7d5c54', '#E7BB96', '#262842', '#2C497F', '#8897BD']
#ccnpalette = ['#828144', '#B6C38D', '#E99E46', '#E7BB96', '#262842', '#2C497F', '#8897BD']
cccorder = ['Bp[C]', 'Cp','Bh[C]',  'Ch', 'DIC','DOC',  'RDOC', ]
cccpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light,DICCOLOR, DOCCOLOR, RDOCCOLOR, ]
#Hex Codes: #49593C, #945C39, #DF5F35, #EF9E84, #FFE3D1
cccpalette = ['#2F6755', '#98A69A', '#7d5c54', '#E7BB96', '#DF5F35', '#EF9E84', '#ffd8d1']

sns.color_palette(ccnpalette)
# Out:
# [(0.1843137254901961, 0.403921568627451, 0.3333333333333333),
#  (0.596078431372549, 0.6509803921568628, 0.6039215686274509),
#  (0.49019607843137253, 0.3607843137254902, 0.32941176470588235),
#  (0.9058823529411765, 0.7333333333333333, 0.5882352941176471),
#  (0.14901960784313725, 0.1568627450980392, 0.25882352941176473),
#  (0.17254901960784313, 0.28627450980392155, 0.4980392156862745),
#  (0.5333333333333333, 0.592156862745098, 0.7411764705882353)]

# %%
 
sns.color_palette([PCOLOR, HCOLOR, PCOLOR_light, HCOLOR_light] )
# Out:
# [(0.6, 0.8, 0.6),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.8235294117647058, 0.6627450980392157)]

# %%
HCOLOR = '#ffc58f'
HCOLOR_light = '#ffd2a9'
PCOLOR = '#99cc99'
PCOLOR_light = '#aad5aa'

DONCOLOR = '#7285b7'
RDONCOLOR = 'black' #'#00334D'
DINCOLOR = '#bbdaff' #'#000066'

DOCCOLOR = '#cc6666'
RDOCCOLOR = 'black' #'#00334D'
DICCOLOR = '#ff9da4' #'#000066'

SHCOLOR = '#ffa98f'
SPCOLOR = '#326232'


ccnpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light, SPCOLOR, SHCOLOR,DONCOLOR, RDONCOLOR, DINCOLOR]
ccnorder = ['Bp', 'Np', 'Bh','Nh',  'ABp', 'ABh', 'DON', 'RDON', 'DIN', ]
cccpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
cccorder = ['Bp[C]', 'Cp', 'Bh[C]', 'Ch', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
ccxpalette = [PCOLOR, HCOLOR]
ccxorder = ['Xp', 'Xh']
hnpalette = [ HCOLOR_light, SPCOLOR, SHCOLOR, DONCOLOR, RDONCOLOR, DINCOLOR]
hnorder = [ 'Bh', 'ABp', 'ABh', 'DON', 'RDON', 'DIN']
hcpalette = [ HCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
hcorder = [ 'Bh[C]', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
pnpalette = [ PCOLOR_light, SPCOLOR, SHCOLOR, DONCOLOR, RDONCOLOR, DINCOLOR]
pnorder = [ 'Bp', 'ABp', 'ABh', 'DON', 'RDON', 'DIN']
pcpalette = [ PCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
pcorder = [ 'Bp[C]', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
sns.color_palette(ccnpalette + cccpalette, )
#
# Out:
# [(0.6, 0.8, 0.6),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (1.0, 0.8235294117647058, 0.6627450980392157),
#  (0.19607843137254902, 0.3843137254901961, 0.19607843137254902),
#  (1.0, 0.6627450980392157, 0.5607843137254902),
#  (0.4470588235294118, 0.5215686274509804, 0.7176470588235294),
#  (0.0, 0.0, 0.0),
#  (0.7333333333333333, 0.8549019607843137, 1.0),
#  (0.6, 0.8, 0.6),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (1.0, 0.8235294117647058, 0.6627450980392157),
#  (0.19607843137254902, 0.3843137254901961, 0.19607843137254902),
#  (1.0, 0.6627450980392157, 0.5607843137254902),
#  (0.8, 0.4, 0.4),
#  (0.0, 0.0, 0.0),
#  (1.0, 0.615686274509804, 0.6431372549019608)]

# %%
HCOLOR_dark = '#A67B5B'
HCOLOR = '#ECB176'
HCOLOR_light = '#803D3B'

PCOLOR_dark = '#006769'
PCOLOR = '#40A578'
PCOLOR_light = '#9DDE8B'


DONCOLOR = '#41C9E2'
RDONCOLOR = 'black' #'#00334D'
DINCOLOR = '#008DDA' #'#000066'

DOCCOLOR = '#FF0000'
RDOCCOLOR = 'black' #'#00334D'
DICCOLOR = '#ff9da4' #'#000066'

SHCOLOR = '#ffa98f'
SPCOLOR = '#326232'


# ccnpalette = [PCOLOR, PCOLOR_light, PCOLOR_dark, HCOLOR, HCOLOR_light, HCOLOR_dark, DONCOLOR, RDONCOLOR, DINCOLOR]
# ccnorder = ['Bp', 'Np', 'Bh','Nh',  'ABp', 'ABh', 'DON', 'RDON', 'DIN', ]
# cccpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
# cccorder = ['Bp[C]', 'Cp', 'Bh[C]', 'Ch', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
# ccxpalette = [PCOLOR, HCOLOR]
# ccxorder = ['Xp', 'Xh']
# hnpalette = [ HCOLOR_light, SPCOLOR, SHCOLOR, DONCOLOR, RDONCOLOR, DINCOLOR]
# hnorder = [ 'Bh', 'ABp', 'ABh', 'DON', 'RDON', 'DIN']
# hcpalette = [ HCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
# hcorder = [ 'Bh[C]', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
# pnpalette = [ PCOLOR_light, SPCOLOR, SHCOLOR, DONCOLOR, RDONCOLOR, DINCOLOR]
# pnorder = [ 'Bp', 'ABp', 'ABh', 'DON', 'RDON', 'DIN']
# pcpalette = [ PCOLOR_light, SPCOLOR, SHCOLOR, DOCCOLOR, RDOCCOLOR, DICCOLOR]
# pcorder = [ 'Bp[C]', 'ABp[C]', 'ABh[C]', 'DOC', 'RDOC', 'DIC']
sns.color_palette(ccnpalette + cccpalette, )
#
# Out:
# [(0.6, 0.8, 0.6),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (1.0, 0.8235294117647058, 0.6627450980392157),
#  (0.19607843137254902, 0.3843137254901961, 0.19607843137254902),
#  (1.0, 0.6627450980392157, 0.5607843137254902),
#  (0.4470588235294118, 0.5215686274509804, 0.7176470588235294),
#  (0.0, 0.0, 0.0),
#  (0.7333333333333333, 0.8549019607843137, 1.0),
#  (0.6, 0.8, 0.6),
#  (0.6666666666666666, 0.8352941176470589, 0.6666666666666666),
#  (1.0, 0.7725490196078432, 0.5607843137254902),
#  (1.0, 0.8235294117647058, 0.6627450980392157),
#  (0.19607843137254902, 0.3843137254901961, 0.19607843137254902),
#  (1.0, 0.6627450980392157, 0.5607843137254902),
#  (0.8, 0.4, 0.4),
#  (0.0, 0.0, 0.0),
#  (1.0, 0.615686274509804, 0.6431372549019608)]

# %%
ccnorder = ['Bp', 'Np','Bh',  'Nh', 'DIN','DON',  'RDON', ]
ccnpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light,DINCOLOR, DONCOLOR, RDONCOLOR, ]

#Hex Codes: #262842, #293961, #2C497F, #8897BD, #E3E4FA
#Hex Codes: #49593C, #945C39, #DF5F35, #EF9E84, #FFE3D1
#Hex Codes: #5E1525, #C74F29, #E99E46, #B6C38D, #828144
#Hex Codes: #094A25, #0C6B37, #F8B324, #EB442C, #BC2023
#Hex Codes: #344E41, #3A5A40, #588157, #5A9F68, #BBD58E
ccnpalette = [PCOLOR, '#5A9F68', HCOLOR, '#ff7e06',  '#4651a9', '#749BC2', '#91C8E4']
#ccnpalette = ['#828144', '#B6C38D', '#E99E46', '#E7BB96', '#262842', '#2C497F', '#8897BD']
cccorder = ['Bp[C]', 'Cp','Bh[C]',  'Ch', 'DIC','DOC',  'RDOC', ]
cccpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light,DICCOLOR, DOCCOLOR, RDOCCOLOR, ]
#Hex Codes: #49593C, #945C39, #DF5F35, #EF9E84, #FFE3D1
cccpalette = [PCOLOR, '#5A9F68', HCOLOR, '#ff7e06', '#C23210', '#D65F59', '#FF8A83']

sns.color_palette(ccnpalette)
# Out:
# [(0.25098039215686274, 0.6470588235294118, 0.47058823529411764),
#  (0.35294117647058826, 0.6235294117647059, 0.40784313725490196),
#  (0.9254901960784314, 0.6941176470588235, 0.4627450980392157),
#  (1.0, 0.49411764705882355, 0.023529411764705882),
#  (0.27450980392156865, 0.3176470588235294, 0.6627450980392157),
#  (0.4549019607843137, 0.6078431372549019, 0.7607843137254902),
#  (0.5686274509803921, 0.7843137254901961, 0.8941176470588236)]

# %%
cccorder3 = ['Bp[C]', 'Cp','Bh[C]',  'Ch','DOC',  'RDOC', ]
#cccpalette = [PCOLOR, PCOLOR_light, HCOLOR, HCOLOR_light,DICCOLOR, DOCCOLOR, RDOCCOLOR, ]
#Hex Codes: #49593C, #945C39, #DF5F35, #EF9E84, #FFE3D1
cccpalette3 = [PCOLOR, '#5A9F68', HCOLOR, '#ff7e06', '#D65F59', '#FF8A83']

# %%
PCOLOR = '#A0E34D'
HCOLOR = '#D6AE5F'

ccnorder1 = ['Bptotal[N]', 'Bhtotal[N]', 'DIN','DON',  'RDON', ]
ccnpalette3 = ['#3A5A40', '#D4AF37',  '#262842', '#2C497F', '#8897BD']
ccnpalette4 = ['#3A5A40', '#D4AF37',  '#4651a9', '#749BC2', '#91C8E4']
ccnpalette1 = [PCOLOR,HCOLOR,  '#262842', '#749BC2', DINCOLOR]
ccnpalette2 = [PCOLOR,HCOLOR,  DINCOLOR, DONCOLOR, RDONCOLOR]

cccorder1 = ['Bptotal[C]', 'Bhtotal[C]', 'DIC','DOC',  'RDOC', ]
cccpalette1 = [PCOLOR,HCOLOR,  '#C23210', '#D65F59', '#FF8A83']

cccorder1 = ['Bptotal[C]', 'Bhtotal[C]', 'DOC',  'RDOC', ]
cccpalette1 = [PCOLOR,HCOLOR,  '#D65F59', '#FF8A83']

sns.color_palette(ccnpalette1+  ccnpalette2+  ccnpalette3 )# + ccnpalette4)
#sns.color_palette(cccpalette1)
# Out:
# [(0.6274509803921569, 0.8901960784313725, 0.30196078431372547),
#  (0.8392156862745098, 0.6823529411764706, 0.37254901960784315),
#  (0.14901960784313725, 0.1568627450980392, 0.25882352941176473),
#  (0.4549019607843137, 0.6078431372549019, 0.7607843137254902),
#  (0.0, 0.5529411764705883, 0.8549019607843137),
#  (0.6274509803921569, 0.8901960784313725, 0.30196078431372547),
#  (0.8392156862745098, 0.6823529411764706, 0.37254901960784315),
#  (0.0, 0.5529411764705883, 0.8549019607843137),
#  (0.2549019607843137, 0.788235294117647, 0.8862745098039215),
#  (0.0, 0.0, 0.0),
#  (0.22745098039215686, 0.35294117647058826, 0.25098039215686274),
#  (0.8313725490196079, 0.6862745098039216, 0.21568627450980393),
#  (0.14901960784313725, 0.1568627450980392, 0.25882352941176473),
#  (0.17254901960784313, 0.28627450980392155, 0.4980392156862745),
#  (0.5333333333333333, 0.592156862745098, 0.7411764705882353)]

# %%
gorder1 = gorder[:2] + [gorder[3]]
gpalette1 = gpalette[:2] + [gpalette[3]]

# %%
vCcolors = {
 'deathC_DOCp' : cccpalette[0], 
    'deathC_DOCh' : cccpalette[2],
    'gross_uptakeOCh' : cccpalette[3],
    'gross_uptakeICp' : cccpalette[1],  
 'respirationCp': PCOLOR_light,  
    'respirationCh': HCOLOR_light, 
}

#     dDICdt = dic_air_water_exchange + np.sum(respirationC - gross_uptake[DIC_IDX,:])
#     dDOCdt = np.sum(
#         deathC * paramgammaD + overflowC - gross_uptake[DOC_IDX,:])

vCorder = dict()
vCorder['DOC_pos'] = [
    'deathC_DOCp', 'deathC_DOCh',
]
vCorder['DOC_neg'] = [
     'gross_uptakeOCh',
]
vCorder['DIC_pos'] = [
    'respirationCp', 'respirationCh'
    
]
vCorder['DIC_neg'] = [
    'gross_uptakeICp',  
]
vCdf = dict()
# for y in gorder1:
#     vCdf[y] = dict()
#     for i in vCorder:    
#         mdfDIC = mdf.loc[mdf['variable'].isin(vCorder[i]) & mdf.y_pred.isin([y])]
#         dfDIC = mdfDIC.pivot(columns='variable', index='day', values='value')
#         vCdf[y][i] = dfDIC

# %%
vNcolors = {
 'deathN_DONp' : ccnpalette[0], 
    'deathN_DONh' : ccnpalette[2],
    'DON2DIN' : ccnpalette[5], 
    'DON2DIN_exoh' : ccnpalette[4],
    'gross_uptakeONh' : ccnpalette[3],
    'gross_uptakeINp' : ccnpalette[1],  
    'gross_uptakeINh' : HCOLOR_light,
}

vNorder = dict()
vNorder['DON_pos'] = [
    'deathN_DONp', 'deathN_DONh',
]
vNorder['DON_neg'] = [
     'gross_uptakeONh',
     'DON2DIN', 
        'DON2DIN_exoh'
]
vNorder['DIN_pos'] = [
     'DON2DIN', 
        'DON2DIN_exoh'
    
]
vNorder['DIN_neg'] = [
    'gross_uptakeINp',  
    'gross_uptakeINh',
]
# vNdf = dict()
# for y in gorder1:
#     vNdf[y] = dict()
#     for i in vNorder:    
#         mdfDIN = mdf.loc[mdf['variable'].isin(vNorder[i]) & mdf.y_pred.isin([y])]
#         dfDIN = mdfDIN.pivot(columns='variable', index='day', values='value')
#         vNdf[y][i] = dfDIN

# %%
orig_predicted_classes_df =  pd.read_csv('../results/final/het/predicted_classes_monte_het_clean.csv.gz',)
orig_df = pd.read_csv('../results/final/het/monte_het_clean_clean_df.csv.gz',)

# %%
dpath = '../results/rerun_sensitivity_init/clean/'
fnames = [
    'rerun_het_DIN800_init_clean_df.csv.gz',
    'rerun_het_DIN800DOC2750_init_clean_df.csv.gz',
    'rerun_het_DIN800DOC160_init_clean_df.csv.gz',
    'rerun_het_DOC2750_init_clean_df.csv.gz',
    'rerun_het_DOC160_init_clean_df.csv.gz',
]    
def _readvfile(fname):
    category = fname.replace(dpath,'').replace('rerun_het_','').replace('_init_clean_df.csv.gz','')
    print (fname, category)
    df = pd.read_csv(fname)
    df['Category'] = category
    return df
df = pd.concat([_readvfile(os.path.join(dpath,f)) for f in fnames], ignore_index=True)
# Out:
# ../results/rerun_sensitivity_init/clean/rerun_het_DIN800_init_clean_df.csv.gz DIN800
# ../results/rerun_sensitivity_init/clean/rerun_het_DIN800DOC2750_init_clean_df.csv.gz DIN800DOC2750
# ../results/rerun_sensitivity_init/clean/rerun_het_DIN800DOC160_init_clean_df.csv.gz DIN800DOC160
# ../results/rerun_sensitivity_init/clean/rerun_het_DOC2750_init_clean_df.csv.gz DOC2750
# ../results/rerun_sensitivity_init/clean/rerun_het_DOC160_init_clean_df.csv.gz DOC160

# %%
orig_df['Category'] = 'Original'
orig_predicted_classes_df['Category'] = 'Original'

# %%
df = pd.concat([df, orig_df], ignore_index=True)

# %%
dpath = '../results/rerun_sensitivity_init/clean'
fnames = [
    'predicted_classes_rerun_het_DIN800DOC2750_init.csv.gz',
    'predicted_classes_rerun_het_DIN800DOC160_init.csv.gz',
    'predicted_classes_rerun_het_DIN800_init.csv.gz',
    'predicted_classes_rerun_het_DOC2750_init.csv.gz',
    'predicted_classes_rerun_het_DOC160_init.csv.gz',
]
def _readvfile(fname):
    category = fname.replace(dpath,'').replace('/predicted_classes_rerun_het_','').replace('_init.csv.gz','')
    print (fname, category)
    df = pd.read_csv(fname)
    df['Category'] = category
    return df
predicted_classes_df = pd.concat([_readvfile(os.path.join(dpath,f)) for f in fnames], ignore_index=True)
predicted_classes_df = pd.concat([predicted_classes_df,orig_predicted_classes_df], ignore_index=True)
# Out:
# ../results/rerun_sensitivity_init/clean/predicted_classes_rerun_het_DIN800DOC2750_init.csv.gz DIN800DOC2750
# ../results/rerun_sensitivity_init/clean/predicted_classes_rerun_het_DIN800DOC160_init.csv.gz DIN800DOC160
# ../results/rerun_sensitivity_init/clean/predicted_classes_rerun_het_DIN800_init.csv.gz DIN800
# ../results/rerun_sensitivity_init/clean/predicted_classes_rerun_het_DOC2750_init.csv.gz DOC2750
# ../results/rerun_sensitivity_init/clean/predicted_classes_rerun_het_DOC160_init.csv.gz DOC160

# %%
#df = pd.merge(df, predicted_classes_df[['model', 'VPRO',  'run_id', 'y_pred',]], on='run_id', how='left')

# %%
DEFAULT_DOC = 20
DEFAULT_DIN = 100
docmap ={
    'Original' : DEFAULT_DOC,
    'DOC160' : 160,
    'DOC2750' : 2750, 
    'DIN800DOC160' : 160,  
    'DIN800' : DEFAULT_DOC, 
    'DIN800DOC2750' : 2750,
}
dinmap ={
    'Original' : DEFAULT_DIN,    
    'DOC160' : DEFAULT_DIN,
    'DOC2750' : DEFAULT_DIN, 
    'DIN800DOC160' : 800,  
    'DIN800' : 800, 
    'DIN800DOC2750' :800,
}

# %%
df['DOC'] = df['Category'].map(docmap)
df['DIN'] = df['Category'].map(dinmap)

# %%
df['DOC'] = df['Category'].map(docmap)
df['DIN'] = df['Category'].map(dinmap)

# %%
predicted_classes_df.groupby(['Category',]).size() # .run_id.nunique()
# Out:
# Category
# DIN800           17757
# DIN800DOC160     17695
# DIN800DOC2750    14245
# DOC160           17753
# DOC2750          11352
# Original         17948
# dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
fpath_ponly = '../results/rerun_sensitivity_ponly/clean/rerun_sensitivity_ponly_clean_df.csv.gz'
ponly_df = pd.read_csv(fpath_ponly)
ponly_df[['id', 'media', 'which', 'model', 'hash']] =     ponly_df.run_id.str.rsplit('_', n=4, expand=True)
ponly_df['Category'] = ponly_df['id'].str.split('_', expand=True)[2]

# %%
ponly_df['DOC'] = ponly_df['Category'].map(docmap)
ponly_df['DIN'] = ponly_df['Category'].map(dinmap)

# %%
ponly_df[['Category', 'DIN', 'DOC']].value_counts()
# Out:
# Category       DIN    DOC
# DIN800         800.0  20.0      12062
# DIN800DOC160   800.0  160.0     12062
# DIN800DOC2750  800.0  2750.0    12062
# DOC160         100.0  160.0     12062
# DOC2750        100.0  2750.0    12062
# Original       100.0  20.0      12062
# Name: count, dtype: int64

# %%
runids = predicted_classes_df.groupby(['Category', 'model', 'y_pred'
                                      ])['run_id'].sample(5 , replace=True)

# %%
predicted_classes_df.loc[predicted_classes_df.run_id.isin(runids)].groupby(['Category', 'model', 'y_pred']).size() # .run_id.nunique()
# Out:
# Category  model      y_pred
# DIN800    EXOENZYME  Neutral      5
#                      Other        5
#                      Strong       5
#                      Sustained    3
#                      Weak         4
#                                  ..
# Original  ROS        Neutral      5
#                      Other        5
#                      Strong       5
#                      Sustained    4
#                      Weak         5
# Length: 146, dtype: int64

# %%
sample_df = df.loc[df.run_id.isin(runids)]
sample_df = pd.merge(sample_df, predicted_classes_df[['model', 'VPRO',  'run_id', 'y_pred',]], on='run_id', how='left')

# %%
ponly_runids = ponly_df.groupby(['Category', 'model',])['run_id'].sample(3 , replace=True)
sample_ponly_df =ponly_df.loc[ponly_df.run_id.isin(ponly_runids)]

# %%
sample_df = df.loc[df.run_id.isin(runids)]
sample_df = pd.merge(sample_df, predicted_classes_df[['model', 'VPRO',  'run_id', 'y_pred',]], on='run_id', how='left')

# %%
df
# Out:
#                Bp        Np         Cp         Bh        Nh            Ch  \
# 0        0.892857  0.000000   0.000000  28.571429  0.000000  0.000000e+00
# 1        1.383107  0.952480   3.072298  26.840583  7.466600  1.170366e-20
# 2        2.785310  1.929546   6.239568  22.662190  8.124763  9.589174e-21
# 3        4.063183  2.814917   9.100323  21.160475  7.883966  2.177024e-03
# 4        7.798133  5.403021  17.443301  19.976307  6.285946  6.433963e-01
# ...           ...       ...        ...        ...       ...           ...
# 7159495  0.063991  0.008294   0.224506   0.074848  0.023026  2.283230e-02
# 7159496  0.063768  0.008265   0.223723   0.074587  0.022946  2.275272e-02
# 7159497  0.063635  0.008248   0.223255   0.074431  0.022898  2.270508e-02
# 7159498  0.063499  0.008230   0.222780   0.074273  0.022849  2.265680e-02
# 7159499  0.063184  0.008189   0.221674   0.073904  0.022736  2.254429e-02
#
#                DON       RDON  DIN  DOC  ...   deathN_DONh      Bp[C]  \
# ...

# %%
sample_df
# Out:
#               Bp         Np          Cp         Bh        Nh        Ch  \
# 0       0.892857   0.000000    0.000000  28.571429  0.000000  0.000000
# 1       2.678436   1.419064    8.720387  24.555882  6.441848  1.469557
# 2      11.323371   6.012644   36.939403  19.758476  5.320801  1.863502
# 3      24.574301  13.050885   80.131779  19.048394  5.337628  2.831731
# 4      93.143046  49.524946  302.622553  25.511690  8.106585  8.611665
# ...          ...        ...         ...        ...       ...       ...
# 49797   0.126024   0.017397    0.441215   0.090035  0.021957  0.005418
# 49798   0.124931   0.017246    0.437385   0.089253  0.021766  0.005371
# 49799   0.124278   0.017156    0.435102   0.088788  0.021652  0.005343
# 49800   0.123620   0.017065    0.432796   0.088317  0.021538  0.005314
# 49801   0.122093   0.016854    0.427450   0.087226  0.021271  0.005249
#
#              DON        RDON  DIN  DOC  ...  Bptotal[C]       Bh[C]  \
# ...

# %%
msample_df = sample_df.melt(
    id_vars=['model','Category', 'DOC', 'DIN','y_pred', 'day', 'run_id'], value_vars=[ 'Bptotal[N]', 'Bhtotal[N]'],
    value_name='μM N',
)
msample_df['Strain'] = msample_df['variable'].map({'Bptotal[N]' : 'vPro', 'Bhtotal[N]': 'vHet'})

# %%
PCOLOR
# Out:
# '#A0E34D'

# %%
for din in [100,800]:
    g = sns.relplot(
        data=msample_df.loc[msample_df.DIN.isin([din])], 
        x='day', y='μM N',
        hue='Strain', hue_order=['vHet', 'vPro',], palette=[ HCOLOR, PCOLOR,],
        estimator=None, units='run_id',
        kind='line', lw=0.5,
        row='DOC', 
        col='model', col_order=morder, #row_order=media_order,
        height=1.5, aspect=1, rasterized=True,
        facet_kws=dict(margin_titles=True),
        legend=False,
    )
    g.set_titles(col_template='{col_name}')
    for (row_val, col_val), ax in g.axes_dict.items():
        sns.lineplot(
            data=sample_ponly_df.loc[sample_ponly_df.model.isin([col_val]) & sample_ponly_df.DOC.isin([row_val]) & sample_ponly_df.DIN.isin([din])],
            x='day', y='Bptotal[N]',
            color='black', 
            estimator=None, units='run_id',
            lw=0.5, ax=ax,  rasterized=True,
            legend=False,
        )
    plt.suptitle(f'DIN = {din}',y=1.02)

# %%
def _compute_lastday_features(df, groupby_cols, nutrient, biomass_prefix):
    bcol=f'{biomass_prefix}[{nutrient}]'
    lod_lastday_threshold = 5
    refmaxday_df = df.loc[df[bcol].ge(lod_lastday_threshold)].groupby(groupby_cols).day.max()
    #refmaxday_df.rename(columns=dict(day=f'last_day{nutrient}'), inplace=True)
    refmaxday_df.name = f'last_day{nutrient}'
    return refmaxday_df

# %%
from scipy.signal import find_peaks
def _count_peaks(x):
    peaks, peak_props = find_peaks(x, prominence=5, height=5)
    return len(peaks)
    
def _compute_count_peaks(df, groupby_cols, nutrient, biomass_prefix):
    bcol=f'{biomass_prefix}[{nutrient}]'
    refmaxday_df = df.groupby(groupby_cols)[bcol].apply(_count_peaks)
    refmaxday_df.name = 'peaks'
    return refmaxday_df

# %%
_compute_count_peaks(df.loc[df.run_id.isin(runids[10:])], 'run_id', 'N', 'Bptotal')
# Out:
# run_id
# monte_EXOENZYME_11_monte_vpro_57_7_EXOENZYME_C2_26_lowN_all_EXOENZYME_h8519271514136708373      1
# monte_EXOENZYME_11_monte_vpro_59_94_EXOENZYME_C2_61_lowN_all_EXOENZYME_h8519271514136708373     1
# monte_EXOENZYME_20_monte_vpro_58_74_EXOENZYME_C1_24_lowN_all_EXOENZYME_h8519271514136708373     1
# monte_EXOENZYME_24_monte_vpro_58_71_EXOENZYME_C4_14_lowN_all_EXOENZYME_h8519271514136708373     1
# monte_EXOENZYME_29_monte_vpro_77_45_EXOENZYME_C3_60_lowN_all_EXOENZYME_h8519271514136708373     1
#                                                                                                ..
# rerun_het_DOC2750_monte_ROS_67_monte_vpro_90_89_ROS_C0_37_lowN_all_ROS_h-8660846992299669535    1
# rerun_het_DOC2750_monte_ROS_70_monte_vpro_19_33_ROS_C0_25_lowN_all_ROS_h-8660846992299669535    1
# rerun_het_DOC2750_monte_ROS_72_monte_vpro_64_23_ROS_C2_42_lowN_all_ROS_h-8660846992299669535    0
# ...

# %%
run_ids_tmp = max_day_df_ponly.loc[max_day_df_ponly.num_peaks>1,'run_id']

# %%
df.head().run_id.unique()
run_id = 'monte_OVERFLOW_fix_OVERFLOW_25_monte_vpro_2_47_15_OVERFLOW_93_lowN_all_OVERFLOW_h6878164821315599434'
tdf = df.loc[df.run_id.isin(runids2)]

# %%
tdf[['day', 'Bptotal[N]']]
# Out:
#                 day  Bptotal[N]
# 590298     0.000000    0.892857
# 590299     1.081944    1.912879
# 590300     2.164583    3.235055
# 590301     2.747222    4.290533
# 590302     3.754167    6.989069
# ...             ...         ...
# 3026225  110.943750    0.038589
# 3026226  115.845833    0.025627
# 3026227  118.788889    0.020091
# 3026228  121.777778    0.015733
# 3026229  128.767361    0.009013
#
# [222 rows x 2 columns]

# %%
from scipy.signal import find_peaks
peaks, peak_props = find_peaks(tdf['Bptotal[N]'], prominence=2, height=1)

# %%
peaks
sns.relplot(
    data=tdf,
    x='day', y='Bptotal[N]',
    kind='line',
    hue='run_id', legend=False,
)
plt.plot(tdf['day'].iloc[peaks], tdf['Bptotal[N]'].iloc[peaks], 'ro', label='Peaks')

# %%
max_day_df = df.loc[df.groupby('run_id')['Bptotal[N]'].idxmax()]
max_day_df_ponly = ponly_df.loc[ponly_df.groupby('run_id')['Bptotal[N]'].idxmax()]

# %%
max_day_df['last_day'] = max_day_df['run_id'].map(_compute_lastday_features(df, 'run_id', 'N', 'Bptotal'))
max_day_df_ponly['last_day'] = max_day_df_ponly['run_id'].map(_compute_lastday_features(ponly_df, 'run_id', 'N', 'Bptotal'))

# %%
max_day_df['num_peaks'] = max_day_df['run_id'].map(_compute_count_peaks(df, 'run_id', 'N', 'Bptotal'))
max_day_df_ponly['num_peaks'] = max_day_df_ponly['run_id'].map(_compute_count_peaks(ponly_df, 'run_id', 'N', 'Bptotal'))

# %%
max_day_df = pd.merge(max_day_df, predicted_classes_df[['model', 'VPRO',  'run_id', 'y_pred',]], on='run_id', how='left')

# %%
max_day_df['Simulation'] = 'Coculture'
max_day_df_ponly['Simulation'] = 'vPro Monoculture'

# %%
max_day_df = pd.concat([max_day_df, max_day_df_ponly],ignore_index=True)

# %%
max_day_df.rename(columns={'day': 'max_day'}, inplace=True)

# %%
max_day_df.columns
# Out:
# Index(['Bp', 'Np', 'Cp', 'Bh', 'Nh', 'Ch', 'DON', 'RDON', 'DIN', 'DOC', 'RDOC',
#        'DIC', 'ROS', 't', 'max_day', 'gross_uptakeINp', 'gross_uptakeINh',
#        'gross_uptakeONp', 'gross_uptakeONh', 'gross_uptakeICp',
#        'gross_uptakeICh', 'gross_uptakeOCp', 'gross_uptakeOCh', 'uptakeNp',
#        'uptakeNh', 'uptakeCp', 'uptakeCh', 'QCp', 'QCh', 'biosynthesisNp',
#        'biosynthesisNh', 'respirationCp', 'respirationCh',
#        'biomass_breakdownCp', 'biomass_breakdownCh', 'overflowNp',
#        'overflowNh', 'overflowCp', 'overflowCh', 'ROSproductionp',
#        'ROSproductionh', 'ROSlossp', 'ROSlossh', 'deathbiomassNp',
#        'deathbiomassNh', 'deathstoreNp', 'deathstoreNh', 'deathstoreCp',
#        'deathstoreCh', 'DON2DIN_exop', 'DON2DIN_exoh', 'DON2DIN',
#        'additionalLossRatep', 'additionalLossRateh', 'regNp', 'regNh', 'regCp',
#        'regCh', 'deathC_DOCp', 'deathC_DOCh', 'deathN_DONp', 'deathN_DONh',
# ...

# %%
max_day_df.num_peaks.describe()
# Out:
# count    98054.000000
# mean         0.901218
# std          0.323464
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: num_peaks, dtype: float64

# %%
max_day_df[['run_id', 'model', 'Category', 'DIN', 'DOC', 'Simulation', 'num_peaks', 'max_day', 'last_day', ]].to_csv('../results/rerun_sensitivity_init/rerun_sensitivity_init_maxday.csv.gz', index=False)

# %%
max_day_df.loc[max_day_df.Simulation.isin(['Coculture']) & max_day_df.num_peaks.gt(2), ['Category']]
# Out:
#             Category
# 18182   DIN800DOC160
# 18636   DIN800DOC160
# 19914   DIN800DOC160
# 19917   DIN800DOC160
# 21081   DIN800DOC160
# 21829   DIN800DOC160
# 37778  DIN800DOC2750
# 38759  DIN800DOC2750
# 50123         DIN800
# 50434         DIN800
# 50512         DIN800
# 50583         DIN800
# 51008         DIN800
# 51865         DIN800
# 53040         DIN800
# 53794         DIN800
# 54479         DIN800
# 54794         DIN800
# 55081         DIN800

# %%
runids2 = max_day_df.loc[max_day_df.Simulation.isin(['Coculture']) & max_day_df.num_peaks.gt(1)].groupby(['Category', 'model', ])['run_id'].sample(1)
runids2
# Out:
# 56025    rerun_het_DIN800_monte_EXOENZYME_98_monte_vpro...
# 57662    rerun_het_DIN800_monte_MIN_74_monte_vpro_18_48...
# 58759    rerun_het_DIN800_monte_MIXOTROPH_29_monte_vpro...
# 63610    rerun_het_DIN800_monte_OVERFLOW_fix_OVERFLOW_6...
# 66798    rerun_het_DIN800_monte_ROS_65_monte_vpro_28_63...
# 18489    rerun_het_DIN800DOC160_monte_EXOENZYME_18_mont...
# 24822    rerun_het_DIN800DOC160_monte_MIN_37_monte_vpro...
# 28173    rerun_het_DIN800DOC160_monte_MIXOTROPH_83_mont...
# 28837    rerun_het_DIN800DOC160_monte_OVERFLOW_fix_OVER...
# 34496    rerun_het_DIN800DOC160_monte_ROS_53_monte_vpro...
# 37930    rerun_het_DIN800DOC2750_monte_EXOENZYME_58_mon...
# 44108    rerun_het_DIN800DOC2750_monte_OVERFLOW_fix_OVE...
# 48587    rerun_het_DIN800DOC2750_monte_ROS_34_monte_vpr...
# 68024    rerun_het_DOC160_monte_EXOENZYME_15_monte_vpro...
# 78978    rerun_het_DOC160_monte_OVERFLOW_fix_OVERFLOW_1...
# 86392    rerun_het_DOC2750_monte_EXOENZYME_42_monte_vpr...
# ...

# %%
runids3 = max_day_df.loc[max_day_df.Simulation.isin(['Coculture']) & max_day_df.num_peaks.gt(2)].groupby(['Category', 'model', ])['run_id'].sample(1)
runids3
# Out:
# 50434    rerun_het_DIN800_monte_EXOENZYME_18_monte_vpro...
# 21081    rerun_het_DIN800DOC160_monte_EXOENZYME_55_mont...
# 37778    rerun_het_DIN800DOC2750_monte_EXOENZYME_55_mon...
# Name: run_id, dtype: object

# %%
sample_df2 = df.loc[df.run_id.isin(runids2)]
sample_df2 = pd.merge(sample_df2, max_day_df[['model', 'num_peaks', 'run_id',]], on='run_id', how='left')

# %%
sample_df3 = df.loc[df.run_id.isin(runids3)]
sample_df3 = pd.merge(sample_df3, max_day_df[['model', 'num_peaks', 'run_id',]], on='run_id', how='left')

# %%
msample_df2 = sample_df2.melt(
    id_vars=['model','Category', 'DOC', 'DIN', 'day', 'run_id', ], value_vars=[ 'Bptotal[N]', 'Bhtotal[N]'],
    value_name='μM N',
)
msample_df2['Strain'] = msample_df2['variable'].map({'Bptotal[N]' : 'vPro', 'Bhtotal[N]': 'vHet'})

# %%
msample_df3 = sample_df3.melt(
    id_vars=['model','Category', 'DOC', 'DIN', 'day', 'run_id', ], value_vars=[ 'Bptotal[N]', 'Bhtotal[N]'],
    value_name='μM N',
)
msample_df3['Strain'] = msample_df3['variable'].map({'Bptotal[N]' : 'vPro', 'Bhtotal[N]': 'vHet'})

# %%
for din in [100,800]:
    g = sns.relplot(
        data=msample_df2.loc[msample_df2.DIN.isin([din])], 
        x='day', y='μM N',
        hue='Strain', hue_order=['vHet', 'vPro',], palette=[ HCOLOR, PCOLOR,],
        estimator=None, units='run_id',
        kind='line', #lw=0.5,
        row='DOC', col='model', col_order=morder,
        #row='Category', col='model', col_order=morder, #row_order=media_order,
        height=2, aspect=1.2, rasterized=True,
        facet_kws=dict(margin_titles=True, sharey=False),
    )
    # for (row_val, col_val), ax in g.axes_dict.items():
    #     sns.lineplot(
    #         data=sample_ponly_df.loc[sample_ponly_df.model.isin([m]) & sample_ponly_df.DOC.isin([row_val]) & sample_ponly_df.DIN.isin([col_val])],
    #         x='day', y='Bptotal[N]',
    #         color='black', 
    #         estimator=None, units='run_id',
    #         lw=0.2, ax=ax,  rasterized=True,
    #     )
    plt.suptitle(f'DIN = {din}',y=1.02)

# %%
for din in [100,800]:
    g = sns.relplot(
        data=msample_df2.loc[msample_df2.DIN.isin([din]) & 
                msample_df2.Strain.isin(['vPro'])],
        
        x='day', y='μM N',
        color=PCOLOR,
        #hue='Strain', hue_order=['vHet', 'vPro',], palette=[ HCOLOR, PCOLOR,],
        kind='line', #lw=0.5,
        row='DOC', col='model', col_order=morder,
        #row='Category', col='model', col_order=morder, #row_order=media_order,
        height=1.5, aspect=2, rasterized=True,
        facet_kws=dict(margin_titles=True, sharey=False),
    )
    
    for (row_val, col_val), ax in g.axes_dict.items():
        ax2 = ax.twinx()
        sns.lineplot(
            data=msample_df2.loc[msample_df2.model.isin([col_val]) & msample_df2.DOC.isin([row_val]) & msample_df2.DIN.isin([din]) & 
                msample_df2.Strain.isin(['vHet'])],
            x='day', y='μM N',
            color=HCOLOR,
            ax=ax2,  rasterized=True,
        )
        ax2.set_ylabel('vHet', color=HCOLOR)
        ax.set_ylabel('vPro', color=PCOLOR)
    
    plt.suptitle(f'DIN = {din}',y=1.02)
    g.set_titles(col_template='{col_name}', row_template='')
    g.figure.set_layout_engine("constrained")
    plt.show()

# %%
for din in [800]:
    g = sns.relplot(
        data=msample_df3.loc[msample_df3.DIN.isin([din]) & 
                msample_df3.Strain.isin(['vPro'])],
        
        x='day', y='μM N',
        color=PCOLOR,
        #hue='Strain', hue_order=['vHet', 'vPro',], palette=[ HCOLOR, PCOLOR,],
        kind='line', #lw=0.5,
        row='DOC', col='model', #col_order=morder,
        #row='Category', col='model', col_order=morder, #row_order=media_order,
        height=1.5, aspect=2, rasterized=True,
        facet_kws=dict(margin_titles=True, sharey=False),
    )
    
    for (row_val, col_val), ax in g.axes_dict.items():
        ax2 = ax.twinx()
        sns.lineplot(
            data=msample_df3.loc[msample_df3.model.isin([col_val]) & msample_df3.DOC.isin([row_val]) & msample_df3.DIN.isin([din]) & 
                msample_df3.Strain.isin(['vHet'])],
            x='day', y='μM N',
            color=HCOLOR,
            ax=ax2,  rasterized=True,
        )
        ax2.set_ylabel('vHet', color=HCOLOR)
        ax.set_ylabel('vPro', color=PCOLOR)
    
    plt.suptitle(f'DIN = {din}',y=1.02)
    g.set_titles(col_template='{col_name}', row_template='')
    g.figure.set_layout_engine("constrained")
    plt.show()

# %%
msample_df2
# Out:
#             model  Category  DOC  DIN         day  \
# 0       MIXOTROPH    DIN800   20  800    0.000000
# 1       MIXOTROPH    DIN800   20  800    1.081944
# 2       MIXOTROPH    DIN800   20  800    2.164583
# 3       MIXOTROPH    DIN800   20  800    2.747222
# 4       MIXOTROPH    DIN800   20  800    3.754167
# ...           ...       ...  ...  ...         ...
# 206011   OVERFLOW  Original   20  100  110.943750
# 206012   OVERFLOW  Original   20  100  115.845833
# 206013   OVERFLOW  Original   20  100  118.788889
# 206014   OVERFLOW  Original   20  100  121.777778
# 206015   OVERFLOW  Original   20  100  128.767361
#
#                                                    run_id   day_bin  \
# 0       rerun_het_DIN800_monte_MIXOTROPH_5_monte_vpro_...  (20, 40]
# 1       rerun_het_DIN800_monte_MIXOTROPH_5_monte_vpro_...  (20, 40]
# 2       rerun_het_DIN800_monte_MIXOTROPH_5_monte_vpro_...  (20, 40]
# 3       rerun_het_DIN800_monte_MIXOTROPH_5_monte_vpro_...  (20, 40]
# ...

# %%
tmp =  msample_df2.day_bin.unique()[2]
tmp
# Out:
# Interval(40, 130, closed='right')

# %%
msample_df2.loc[msample_df2.model.isin([m]) & msample_df2.Strain.isin(['vPro']) &
        msample_df2.DOC.isin([2750]) & msample_df2.day_bin.isin([tmp]) #& msample_df2.DIN.isin([800])
        ]['DIN'].value_counts()
# Out:
# DIN
# 800    1110
# 100     296
# Name: count, dtype: int64

# %%
for m in morder:
    g = sns.relplot(
        data=msample_df2.loc[msample_df2.model.isin([m]) & #msample_df2.Strain.isin(['vPro']) &
        msample_df2.DOC.isin([2750]) & msample_df2.day_bin.isin([tmp]) & msample_df2.DIN.isin([100])
        ], 
        x='day', y='μM C',
        hue='Strain', hue_order=['vHet', 'vPro',], palette=[ HCOLOR, PCOLOR,],
        #hue='day_bin', #hue_order=gorder, 
        #palette=['#C3B1E1', PCOLOR, 'red'],
        #estimator=None, units='run_id',
        kind='line', lw=0.5,
        col='run_id', col_wrap=6, # col='DIN',
        #row='Category', col='model', col_order=morder, #row_order=media_order,
        height=2, aspect=1.2,  rasterized=True,
        facet_kws=dict(margin_titles=True),
    )
    g.set_titles(col_template='')
    # for (row_val, col_val), ax in g.axes_dict.items():
    #     sns.lineplot(
    #         data=sample_ponly_df.loc[sample_ponly_df.model.isin([m]) & sample_ponly_df.DOC.isin([row_val]) & sample_ponly_df.DIN.isin([col_val])],
    #         x='day', y='Bptotal[C]',
    #         color='black', 
    #         estimator=None, units='run_id',
    #         lw=0.2, ax=ax,  rasterized=True, legend=False,
    #     )
    plt.suptitle(m,y=1.02)

# %%
tmp =  msample_df2.day_bin.unique()[0]
tmp

# %%
for m in morder:
    g = sns.relplot(
        data=msample_df2.loc[msample_df2.model.isin([m]) & #msample_df2.Strain.isin(['vPro']) &
        msample_df2.DOC.isin([2750]) & msample_df2.day_bin.isin([tmp]) & msample_df2.DIN.isin([800])
        ], 
        x='day', y='μM C',
        hue='Strain', hue_order=['vHet', 'vPro',], palette=[ HCOLOR, PCOLOR,],
        #hue='day_bin', #hue_order=gorder, 
        #palette=['#C3B1E1', PCOLOR, 'red'],
        #estimator=None, units='run_id',
        kind='line', lw=0.5,
        col='run_id', col_wrap=6, # col='DIN',
        #row='Category', col='model', col_order=morder, #row_order=media_order,
        height=2, aspect=1.2,  rasterized=True,
        facet_kws=dict(margin_titles=True),
    )
    g.set_titles(col_template='')
    # for (row_val, col_val), ax in g.axes_dict.items():
    #     sns.lineplot(
    #         data=sample_ponly_df.loc[sample_ponly_df.model.isin([m]) & sample_ponly_df.DOC.isin([row_val]) & sample_ponly_df.DIN.isin([col_val])],
    #         x='day', y='Bptotal[C]',
    #         color='black', 
    #         estimator=None, units='run_id',
    #         lw=0.2, ax=ax,  rasterized=True, legend=False,
    #     )
    plt.suptitle(m,y=1.02)
# Out:
# /tmp/ipykernel_172318/1513810198.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   g = sns.relplot(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/work/tools/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'run_id'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
max_day_df.run_id.values
# Out:
# array(['monte_EXOENZYME_100_monte_vpro_11_62_EXOENZYME_C1_29_lowN_all_EXOENZYME_h8519271514136708373',
#        'monte_EXOENZYME_100_monte_vpro_13_69_EXOENZYME_C1_74_lowN_all_EXOENZYME_h8519271514136708373',
#        'monte_EXOENZYME_100_monte_vpro_17_89_EXOENZYME_C2_59_lowN_all_EXOENZYME_h8519271514136708373',
#        ...,
#        'rerun_ponly_Original_monte_ponly_fix_OVERFLOW_94_monte__87_lowN_ponly_OVERFLOW_h6878164821315599434',
#        'rerun_ponly_Original_monte_ponly_fix_OVERFLOW_97_monte__16_lowN_ponly_OVERFLOW_h6878164821315599434',
#        'rerun_ponly_Original_monte_ponly_fix_OVERFLOW_99_monte__15_lowN_ponly_OVERFLOW_h6878164821315599434'],
#       dtype=object)

# %%
max_day_df.loc[max_day_df.run_id.str.contains('97_16'),['run_id', 'VPRO']].values
# Out:
# array([['monte_OVERFLOW_fix_OVERFLOW_100_monte_vpro_2_97_16_OVERFLOW_2_lowN_all_OVERFLOW_h6878164821315599434',
#         'vpro_2_97_16_OVERFLOW'],
#        ['monte_OVERFLOW_fix_OVERFLOW_100_monte_vpro_2_97_16_OVERFLOW_36_lowN_all_OVERFLOW_h6878164821315599434',
#         'vpro_2_97_16_OVERFLOW'],
#        ['monte_OVERFLOW_fix_OVERFLOW_100_monte_vpro_2_97_16_OVERFLOW_46_lowN_all_OVERFLOW_h6878164821315599434',
#         'vpro_2_97_16_OVERFLOW'],
#        ...,
#        ['rerun_het_DOC2500_monte_OVERFLOW_fix_OVERFLOW_94_monte_vpro_2_97_16_OVERFLOW_69_lowN_all_OVERFLOW_h6878164821315599434',
#         'vpro_2_97_16_OVERFLOW'],
#        ['rerun_het_DOC2500_monte_OVERFLOW_fix_OVERFLOW_97_monte_vpro_2_97_16_OVERFLOW_18_lowN_all_OVERFLOW_h6878164821315599434',
#         'vpro_2_97_16_OVERFLOW'],
#        ['rerun_het_DOC2500_monte_OVERFLOW_fix_OVERFLOW_97_monte_vpro_2_97_16_OVERFLOW_77_lowN_all_OVERFLOW_h6878164821315599434',
#         'vpro_2_97_16_OVERFLOW']], dtype=object)

# %%
max_day_df_ponly.loc[max_day_df_ponly.run_id.str.contains('97'),['run_id', ]].values
# Out:
# array([['rerun_ponly_DIN800DOC160_monte_ponly_MIXOTROPH_97_monte__13_lowN_ponly_MIXOTROPH_h-6209959888544056779'],
#        ['rerun_ponly_DIN800DOC160_monte_ponly_ROS_74_monte__97_lowN_ponly_ROS_h-2025029465965034071'],
#        ['rerun_ponly_DIN800DOC160_monte_ponly_ROS_97_monte__23_lowN_ponly_ROS_h-2025029465965034071'],
#        ['rerun_ponly_DIN800DOC160_monte_ponly_fix_OVERFLOW_97_monte__16_lowN_ponly_OVERFLOW_h6878164821315599434'],
#        ['rerun_ponly_DIN800DOC2500_monte_ponly_MIXOTROPH_97_monte__13_lowN_ponly_MIXOTROPH_h-6209959888544056779'],
#        ['rerun_ponly_DIN800DOC2500_monte_ponly_ROS_74_monte__97_lowN_ponly_ROS_h-2025029465965034071'],
#        ['rerun_ponly_DIN800DOC2500_monte_ponly_ROS_97_monte__23_lowN_ponly_ROS_h-2025029465965034071'],
#        ['rerun_ponly_DIN800DOC2500_monte_ponly_fix_OVERFLOW_97_monte__16_lowN_ponly_OVERFLOW_h6878164821315599434'],
# ...
