# %% [markdown]
# # genomic traits analysis for the strains used in the experiment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
sns.set(style="white", context='poster')

# %%
import os
dpath = 'trait_gene_annotations'
os.listdir(dpath)
# Out:
# ['10cc_experimental_traits.xlsx',
#  '10cc_signalP.csv',
#  '42003_2022_3184_MOESM4_ESM_select_genomes.xlsx',
#  'brenda_2024_1.json.tar.gz',
#  'brenda_results_extracellluar enzymes.xlsx',
#  'genetic_traits_table.tsv',
#  'genetic_traits_table_filtered.tsv',
#  'genomes_annotation_long_format.7z',
#  'kegg_pathways.csv',
#  'MASTER_table.tsv',
#  'N related  enzymes.xlsx',
#  'ROS related  enzymes.xlsx',
#  'signalp',
#  'strain_list.csv']

# %%
strains = pd.read_csv(os.path.join(dpath, 'strain_list.csv'))

# %%
strains
# Out:
#                                       Species  \
# 0                     Ruegeria pomeroyi DSS-3
# 1       Pseudoalteromonas haloplanktis TAC125
# 2                Alteromonas macleodii HOT1A3
# 3                 Marinobacter adhaerens HP15
# 4         Phaeobacter gallaeciensis DSM 26640
# 5  Sulfitobacter pseudonitzschiae strain SMR1
# 6                          Roseovrius HOT5_C3
# 7                           Marinovum HOT5_F3
#
#                                        GTDB taxonomy  NCBI taxonID  \
# 0  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...      246200.0
# 1  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...      326442.0
# 2  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...      529120.0
# 3  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...      225937.0
# 4  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...     1423144.0
# 5  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...     1402135.0
# 6  d__Bacteria;p__Pseudomonadota;c__Alphaproteoba...           NaN
# 7  d__Bacteria;p__Pseudomonadota;c__Alphaproteoba...           NaN
#
#   Accession number                             Filename  Filename_Elena
# 0  GCA_000011965.2                        GCA_000011965    246200.7.fna
# 1  GCA_000026085.1                        GCA_000026085    326442.8.fna
# 2       2687454166                           2687453488    28108.53.fna
# 3        650377991                            650377991    225937.3.fna
# 4  GCA_000511385.1                        GCA_000511385   1423144.3.fna
# 5    CeMEB_private  Sulfitobacter_pseudonitzschiae_SMR1  1402135.12.fna
# 6              NaN                                  C03         C03.fna
# 7              NaN                                  F03         F03.fna

# %%
strains['filename'] = strains.Filename_Elena.str.replace('.fna', '', regex=False)

# %%
strain_files = strains.Filename

# %%
traits_df = pd.read_csv(os.path.join(dpath, 'MASTER_table.tsv'), sep='\t', dtype={'filename': str})

# %%
traits_df
# Out:
#                                 filename       locus_tag type    start  \
# 0                              1004786.3  GGNLDHOK_00001  CDS      696
# 1                              1004786.3  GGNLDHOK_00002  CDS     2393
# 2                              1004786.3  GGNLDHOK_00003  CDS     3569
# 3                              1004786.3  GGNLDHOK_00004  CDS     4702
# 4                              1004786.3  GGNLDHOK_00005  CDS     7333
# ...                                  ...             ...  ...      ...
# 59513  GCF_000012345.1_ASM1234v1_genomic  BLEGILBE_01380  CDS  1302965
# 59514  GCF_000012345.1_ASM1234v1_genomic  BLEGILBE_01381  CDS  1304922
# 59515  GCF_000012345.1_ASM1234v1_genomic  BLEGILBE_01382  CDS  1305440
# 59516  GCF_000012345.1_ASM1234v1_genomic  BLEGILBE_01383  CDS  1306297
# 59517  GCF_000012345.1_ASM1234v1_genomic  BLEGILBE_01384  CDS  1307340
#
#            end strand    gene                                         product  \
# 0         2360      +  dnaA_1  Chromosomal replication initiator protein DnaA
# 1         3493      +    dnaN                              Beta sliding clamp
# 2         4693      +    recF         DNA replication and repair protein RecF
# 3         7122      +    gyrB                            DNA gyrase subunit B
# 4         7776      -     NaN                            hypothetical protein
# ...        ...    ...     ...                                             ...
# 59513  1304932      -    mrdA           Peptidoglycan D,D-transpeptidase MrdA
# 59514  1305443      -     NaN                            hypothetical protein
# 59515  1306291      -     NaN                            hypothetical protein
# 59516  1307334      -    mreB             Cell shape-determining protein MreB
# 59517  1308584      -    leuA                      2-isopropylmalate synthase
#
#            db_xref eC_number      KO KEGG_KM KEGG_manual antiSMASH  \
# 0              NaN       NaN  K02313     NaN         NaN       NaN
# 1      COG:COG0592       NaN  K02338     NaN         NaN       NaN
# 2      COG:COG1195       NaN  K03629     NaN         NaN       NaN
# 3      COG:COG0187   5.6.2.2  K02470     NaN         NaN       NaN
# 4              NaN       NaN     NaN     NaN         NaN       NaN
# ...            ...       ...     ...     ...         ...       ...
# 59513  COG:COG0768  3.4.16.4  K05515     NaN         NaN       NaN
# 59514          NaN       NaN  K03571     NaN         NaN       NaN
# 59515          NaN       NaN  K03570     NaN         NaN       NaN
# 59516          NaN       NaN  K03569     NaN         NaN       NaN
# 59517  COG:COG0119  2.3.3.13     NaN     NaN         NaN       NaN
#
#       BioV_transp blast_phytohormones blast_vibrioferrin blast_DMSP dbCAN_CAZy
# 0             NaN                 NaN                NaN        NaN        NaN
# 1             NaN                 NaN                NaN        NaN        NaN
# 2             NaN                 NaN                NaN        NaN        NaN
# 3             NaN                 NaN                NaN        NaN        NaN
# 4             NaN                 NaN                NaN        NaN        NaN
# ...           ...                 ...                ...        ...        ...
# 59513         NaN                 NaN                NaN        NaN        NaN
# 59514         NaN                 NaN                NaN        NaN        NaN
# 59515         NaN                 NaN                NaN        NaN        NaN
# 59516         NaN                 NaN                NaN        NaN        NaN
# 59517         NaN                 NaN                NaN        NaN        NaN
#
# [59518 rows x 19 columns]

# %%
traits_df.loc[traits_df.filename.isin(['GCA_000026085'])].filename.unique()
# Out:
# array([], dtype=object)

# %%
traits_df.loc[~traits_df.filename.isin(strains.filename)].filename.unique()
# Out:
# array(['1004786.3', '1300254.3', '1347342.6', '314275.5', '717774.3',
#        'GCF_000012345.1_ASM1234v1_genomic'], dtype=object)

# %%
strains.loc[~strains.filename.isin(traits_df.filename)]
# Out:
# Empty DataFrame
# Columns: [Species, GTDB taxonomy, NCBI taxonID, Accession number, Filename, Filename_Elena, filename]
# Index: []

# %%
df = traits_df.loc[traits_df.filename.isin(strains.filename)]

# %%
df = pd.merge(df, strains[['filename', 'Species']], on='filename')

# %%
for i in df.columns:
    print(i)
    print(df[i].unique())
# Out:
# filename
# ['1402135.12' '1423144.3' '225937.3' '246200.7' '28108.53' '326442.8'
#  'C03' 'F03']
# locus_tag
# ['ALGBIFEJ_00001' 'ALGBIFEJ_00002' 'ALGBIFEJ_00003' ... 'FLOFJFJI_05679'
#  'FLOFJFJI_05680' 'FLOFJFJI_05681']
# type
# ['CDS' 'tRNA' 'tmRNA' 'rRNA']
# start
# [    7   405   803 ... 97416 97879 98387]
# end
# [  408   806  1381 ... 97826 98265 98743]
# strand
# ['+' '-']
# gene
# [nan 'fadE' 'fadJ_1' ... 'xynR_4' 'dntB' 'mltF_8']
# product
# ['hypothetical protein' 'Acyl-coenzyme A dehydrogenase'
#  'Acetyl-CoA acetyltransferase' ... 'putative oxidoreductase/MSMEI_2347'
#  'Atrazine chlorohydrolase' '4-methyl-5-nitrocatechol 5-monooxygenase']
# db_xref
# [nan 'COG:COG1960' 'COG:COG0183' ... 'COG:COG2706' 'COG:COG4957'
#  'COG:COG2376']
# eC_number
# [nan '1.3.8.7' '2.3.1.9' ... '4.1.2.29' '3.8.1.8' '1.14.13.210']
# KO
# [nan 'K06445' 'K00626' ... 'K06221' 'K07255' 'K07256']
# KEGG_KM
# [nan 'M00087_beta-Oxidation'
#  'M00957_Lysine_degradation,_bacteria,_L-lysine_=>_glutarate_=>_succinate/acetyl-CoA'
#  'M00373_Ethylmalonyl_pathway'
#  'M00036_Leucine_degradation,_leucine_=>_acetoacetate_+_acetyl-CoA'
#  'M00621_Glycine_cleavage_system'
#  'M00307_Pyruvate_oxidation,_pyruvate_=>_acetyl-CoA'
#  'M00009_Citrate_cycle_(TCA_cycle,_Krebs_cycle)'
#  'M00011_Citrate_cycle,_second_carbon_oxidation,_2-oxoglutarate_=>_oxaloacetate'
#  'M00978_Ornithine-ammonia_cycle'
#  'M00741_Propanoyl-CoA_metabolism,_propanoyl-CoA_=>_succinyl-CoA'
#  'M00118_Glutathione_biosynthesis,_glutamate_=>_glutathione'
#  'M00122_Cobalamin_biosynthesis,_cobyrinate_a,c-diamide_=>_cobalamin'
#  'M00120_Coenzyme_A_biosynthesis,_pantothenate_=>_CoA'
#  'M00938_Pyrimidine_deoxyribonucleotide_biosynthesis,_UDP_=>_dTTP'
#  'M00432_Leucine_biosynthesis,_2-oxoisovalerate_=>_2-oxoisocaproate'
#  'M00121_Heme_biosynthesis,_plants_and_bacteria,_glutamate_=>_heme'
#  'M00046_Pyrimidine_degradation,_uracil_=>_beta-alanine,_thymine_=>_3-aminoisobutanoate'
#  'M00115_NAD_biosynthesis,_aspartate_=>_quinolinate_=>_NAD'
#  'M00880_Molybdenum_cofactor_biosynthesis,_GTP_=>_molybdenum_cofactor'
#  'M00051_De_novo_pyrimidine_biosynthesis,_glutamine_(+_PRPP)_=>_UMP'
#  'M00026_Histidine_biosynthesis,_PRPP_=>_histidine'
#  'M00007_Pentose_phosphate_pathway,_non-oxidative_phase,_fructose_6P_=>_ribose_5P'
#  'M00004_Pentose_phosphate_pathway_(Pentose_phosphate_cycle)'
#  'M00549_Nucleotide_sugar_biosynthesis,_glucose_=>_UDP-glucose'
#  'M00909_UDP-N-acetyl-D-glucosamine_biosynthesis,_prokaryotes,_glucose_=>_UDP-GlcNAc'
#  'M00001_Glycolysis_(Embden-Meyerhof_pathway),_glucose_=>_pyruvate'
#  'M00975_Betaine_degradation,_bacteria,_betaine_=>_pyruvate'
#  'M00959_Guanine_ribonucleotide_degradation,_GMP_=>_Urate'
#  'M00958_Adenine_ribonucleotide_degradation,_AMP_=>_Urate'
#  'M00053_Deoxyribonucleotide_biosynthesis,_ADP/GDP/CDP/UDP_=>_dATP/dGTP/dCTP/dUTP'
#  'M00844_Arginine_biosynthesis,_ornithine_=>_arginine' 'M00029_Urea_cycle'
#  'M00526_Lysine_biosynthesis,_DAP_dehydrogenase_pathway,_aspartate_=>_lysine'
#  'M00016_Lysine_biosynthesis,_succinyl-DAP_pathway,_aspartate_=>_lysine'
#  'M00527_Lysine_biosynthesis,_DAP_aminotransferase_pathway,_aspartate_=>_lysine'
#  'M00012_Glyoxylate_cycle' 'M00149_Succinate_dehydrogenase,_prokaryotes'
#  'M00570_Isoleucine_biosynthesis,_threonine_=>_2-oxobutanoate_=>_isoleucine'
#  'M00019_Valine/isoleucine_biosynthesis,_pyruvate_=>_valine_/_2-oxobutanoate_=>_isoleucine'
#  'M00063_CMP-KDO_biosynthesis'
#  'M00028_Ornithine_biosynthesis,_glutamate_=>_ornithine'
#  'M00006_Pentose_phosphate_pathway,_oxidative_phase,_glucose_6P_=>_ribulose_5P'
#  'M00093_Phosphatidylethanolamine_(PE)_biosynthesis,_PA_=>_PS_=>_PE'
#  'M00308_Semi-phosphorylative_Entner-Doudoroff_pathway,_gluconate_=>_glycerate-3P'
#  'M00061_D-Glucuronate_degradation,_D-glucuronate_=>_pyruvate_+_D-glyceraldehyde_3P'
#  'M00555_Betaine_biosynthesis,_choline_=>_betaine'
#  'M00126_Tetrahydrofolate_biosynthesis,_GTP_=>_THF'
#  'M00052_Pyrimidine_ribonucleotide_biosynthesis,_UMP_=>_UDP/UTP,CDP/CTP'
#  'M00049_Adenine_ribonucleotide_biosynthesis,_IMP_=>_ADP,ATP'
#  'M00048_De_novo_purine_biosynthesis,_PRPP_+_glutamine_=>_IMP'
#  'M00169_CAM_(Crassulacean_acid_metabolism),_light'
#  'M00155_Cytochrome_c_oxidase,_prokaryotes'
#  'M00881_Lipoic_acid_biosynthesis,_plants_and_bacteria,_octanoyl-ACP_=>_dihydrolipoyl-E2/H'
#  'M00846_Siroheme_biosynthesis,_glutamyl-tRNA_=>_siroheme'
#  'M00531_Assimilatory_nitrate_reduction,_nitrate_=>_ammonia'
#  'M00008_Entner-Doudoroff_pathway,_glucose-6P_=>_glyceraldehyde-3P_+_pyruvate'
#  'M00010_Citrate_cycle,_first_carbon_oxidation,_oxaloacetate_=>_2-oxoglutarate'
#  'M00060_KDO2-lipid_A_biosynthesis,_Raetz_pathway,_LpxL-LpxM_type;M00866_KDO2-lipid_A_biosynthesis,_Raetz_pathway,_non-LpxL-LpxM_type'
#  'M00003_Gluconeogenesis,_oxaloacetate_=>_fructose-6P'
#  'M00002_Glycolysis,_core_module_involving_three-carbon_compounds;M00552_D-galactonate_degradation,_De_Ley-Doudoroff_pathway,_D-galactonate_=>_glycerate-3P'
#  'M00878_Phenylacetate_degradation,_phenylaxetate_=>_acetyl-CoA/succinyl-CoA'
#  'M00002_Glycolysis,_core_module_involving_three-carbon_compounds'
#  'M00015_Proline_biosynthesis,_glutamate_=>_proline'
#  'M00868_Heme_biosynthesis,_animals_and_fungi,_glycine_=>_heme'
#  'M00049_Adenine_ribonucleotide_biosynthesis,_IMP_=>_ADP,ATP;M00050_Guanine_ribonucleotide_biosynthesis,_IMP_=>_GDP,GTP'
#  'M00156_Cytochrome_c_oxidase,_cbb3-type'
#  'M00022_Shikimate_pathway,_phosphoenolpyruvate_+_erythrose-4P_=>_chorismate'
#  'M00050_Guanine_ribonucleotide_biosynthesis,_IMP_=>_GDP,GTP'
#  'M00017_Methionine_biosynthesis,_aspartate_=>_homoserine_=>_methionine'
#  'M00134_Polyamine_biosynthesis,_arginine_=>_ornithine_=>_putrescine'
#  'M00925_Cobalamin_biosynthesis,_aerobic,_uroporphyrinogen_III_=>_precorrin_2_=>_cobyrinate_a,c-diamide'
#  'M00018_Threonine_biosynthesis,_aspartate_=>_homoserine_=>_threonine'
#  'M00970_Proline_degradation,_proline_=>_glutamate'
#  'M00035_Methionine_degradation'
#  'M00552_D-galactonate_degradation,_De_Ley-Doudoroff_pathway,_D-galactonate_=>_glycerate-3P'
#  'M00017_Methionine_biosynthesis,_aspartate_=>_homoserine_=>_methionine;M00527_Lysine_biosynthesis,_DAP_aminotransferase_pathway,_aspartate_=>_lysine'
#  'M00140_C1-unit_interconversion,_prokaryotes'
#  'M00045_Histidine_degradation,_histidine_=>_N-formiminoglutamate_=>_glutamate'
#  'M00125_Riboflavin_biosynthesis,_plants_and_bacteria,_GTP_=>_riboflavin/FMN/FAD'
#  'M00005_PRPP_biosynthesis,_ribose_5P_=>_PRPP'
#  'M00157_F-type_ATPase,_prokaryotes_and_chloroplasts'
#  'M00040_Tyrosine_biosynthesis,_chorismate_=>_arogenate_=>_tyrosine'
#  'M00027_GABA_(gamma-Aminobutyrate)_shunt'
#  'M00135_GABA_biosynthesis,_eukaryotes,_putrescine_=>_GABA'
#  'M00151_Cytochrome_bc1_complex_respiratory_unit'
#  'M00020_Serine_biosynthesis,_glycerate-3P_=>_serine'
#  'M00535_Isoleucine_biosynthesis,_pyruvate_=>_2-oxobutanoate'
#  'M00793_dTDP-L-rhamnose_biosynthesis'
#  'M00086_beta-Oxidation,_acyl-CoA_synthesis'
#  'M00096_C5_isoprenoid_biosynthesis,_non-mevalonate_pathway'
#  'M00364_C10-C20_isoprenoid_biosynthesis,_bacteria'
#  'M00091_Phosphatidylcholine_(PC)_biosynthesis,_PE_=>_PC'
#  'M00572_Pimeloyl-ACP_biosynthesis,_BioC-BioH_pathway,_malonyl-ACP_=>_pimeloyl-ACP'
#  'M00595_Thiosulfate_oxidation_by_SOX_complex,_thiosulfate_=>_sulfate'
#  'M00627_beta-Lactam_resistance,_Bla_system'
#  'M00123_Biotin_biosynthesis,_pimeloyl-ACP/CoA_=>_biotin'
#  'M00948_Hydroxyproline_degradation,_trans-4-hydroxy-L-proline_=>_2-oxoglutarate'
#  'M00842_Tetrahydrobiopterin_biosynthesis,_GTP_=>_BH4;M00843_L-threo-Tetrahydrobiopterin_biosynthesis,_GTP_=>_L-threo-BH4'
#  'M00117_Ubiquinone_biosynthesis,_prokaryotes,_chorismate_(+_polyprenyl-PP)_=>_ubiquinol'
#  'M00133_Polyamine_biosynthesis,_arginine_=>_agmatine_=>_putrescine_=>_spermidine'
#  'M00119_Pantothenate_biosynthesis,_valine/L-aspartate_=>_pantothenate'
#  'M00345_Formaldehyde_assimilation,_ribulose_monophosphate_pathway'
#  'M00124_Pyridoxal-P_biosynthesis,_erythrose-4P_=>_pyridoxal-P'
#  'M00569_Catechol_meta-cleavage,_catechol_=>_acetyl-CoA_/_4-methylcatechol_=>_propanoyl-CoA'
#  'M00982_Methylcitrate_cycle'
#  'M00018_Threonine_biosynthesis,_aspartate_=>_homoserine_=>_threonine;M00033_Ectoine_biosynthesis,_aspartate_=>_ectoine'
#  'M00021_Cysteine_biosynthesis,_serine_=>_cysteine'
#  'M00579_Phosphate_acetyltransferase-acetate_kinase_pathway,_acetyl-CoA_=>_acetate'
#  'M00855_Glycogen_degradation,_glycogen_=>_glucose-6P'
#  'M00854_Glycogen_biosynthesis,_glucose-1P_=>_glycogen/starch'
#  'M00577_Biotin_biosynthesis,_BioW_pathway,_pimelate_=>_pimeloyl-CoA_=>_biotin'
#  'M00950_Biotin_biosynthesis,_BioU_pathway,_pimeloyl-ACP/CoA_=>_biotin'
#  'M00879_Arginine_succinyltransferase_pathway,_arginine_=>_glutamate'
#  'M00549_Nucleotide_sugar_biosynthesis,_glucose_=>_UDP-glucose;M00855_Glycogen_degradation,_glycogen_=>_glucose-6P'
#  'M00033_Ectoine_biosynthesis,_aspartate_=>_ectoine'
#  'M00548_Benzene_degradation,_benzene_=>_catechol'
#  'M00540_Benzoate_degradation,_cyclohexanecarboxylic_acid_=>pimeloyl-CoA'
#  'M00172_C4-dicarboxylic_acid_cycle,_NADP_-_malic_enzyme_type'
#  'M00119_Pantothenate_biosynthesis,_valine/L-aspartate_=>_pantothenate;M00913_Pantothenate_biosynthesis,_2-oxoisovalerate/spermine_=>_pantothenate'
#  'M00011_Citrate_cycle,_second_carbon_oxidation,_2-oxoglutarate_=>_oxaloacetate;M00012_Glyoxylate_cycle'
#  'M00168_CAM_(Crassulacean_acid_metabolism),_dark'
#  'M00919_Ectoine_degradation,_ectoine_=>_aspartate'
#  'M00913_Pantothenate_biosynthesis,_2-oxoisovalerate/spermine_=>_pantothenate'
#  'M00533_Homoprotocatechuate_degradation,_homoprotocatechuate_=>_2-oxohept-3-enedioate'
#  'M00529_Denitrification,_nitrate_=>_nitrogen'
#  'M00632_Galactose_degradation,_Leloir_pathway,_galactose_=>_alpha-D-glucose-1P'
#  'M00554_Nucleotide_sugar_biosynthesis,_galactose_=>_UDP-galactose'
#  'M00044_Tyrosine_degradation,_tyrosine_=>_homogentisate'
#  'M00176_Assimilatory_sulfate_reduction,_sulfate_=>_H2S'
#  'M00744_Cationic_antimicrobial_peptide_(CAMP)_resistance,_protease_PgtE'
#  'M00023_Tryptophan_biosynthesis,_chorismate_=>_tryptophan'
#  'M00631_D-Galacturonate_degradation_(bacteria),_D-galacturonate_=>_pyruvate_+_D-glyceraldehyde_3P'
#  'M00939_Pyrimidine_degradation,_uracil_=>_3-hydroxypropanoate'
#  'M00153_Cytochrome_bd_ubiquinol_oxidase'
#  'M00417_Cytochrome_o_ubiquinol_oxidase'
#  'M00064_ADP-L-glycero-D-manno-heptose_biosynthesis'
#  'M00597_Anoxygenic_photosystem_II'
#  'M00061_D-Glucuronate_degradation,_D-glucuronate_=>_pyruvate_+_D-glyceraldehyde_3P;M00631_D-Galacturonate_degradation_(bacteria),_D-galacturonate_=>_pyruvate_+_D-glyceraldehyde_3P'
#  'M00623_Phthalate_degradation,_phthalate_=>_protocatechuate']
# KEGG_manual
# [nan 'DHPS_catabolism' 'Taurine_in_TCA']
# antiSMASH
# [nan 'hserlactone' 'NRPS-like' 'RiPP-like' 'terpene' 'betalactone' 'NRPS'
#  'tropodithietic-acid' 'redox-cofactor' 'NI-siderophore' 'ectoine'
#  'butyrolactone' 'arylpolyene' 'RRE-containing' 'T3PKS']
# BioV_transp
# [nan '2.A.6.2.46|[limonene]'
#  '2.A.56.3.4|[3-methyl-2-oxobutanoate,pyruvate,2-oxobutanoate,3-methyl-2-oxovalerate,4-methyl-2-oxopentanoicacid]'
#  '2.A.56.3.3|[monocarboxylicacidanion,pyruvate]' '9.B.104.1.4|[serine]'
#  '2.A.66.4.5|[keto-D-fructose6-phosphate]' '3.A.25.2.1|[peptide]'
#  '2.A.103.1.2|[alpha-D-FucNAc4-(1->4)-beta-D-ManNAcA-(1->4)-D-GlcNAc-undecaprenyldiphosphate(3-)]'
#  '3.A.1.122.15|[cation]' '3.A.1.17.13|[riboflavin]' '2.A.88.1.6|[biotin]'
#  '2.A.56.3.1|[sodium(1+),glutamate(2-)]' '3.A.1.5.11|[glutathione]'
#  '3.A.1.5.39|[tripeptide,dipeptide]'
#  '2.A.80.1.1|[tricarboxylicacidtrianion]'
#  '3.A.1.14.22|[desferrioxamineBmesylate]' '2.A.66.1.32|[hydron,drug]'
#  '2.A.76.1.1|[homoserine,homoserinelactone]'
#  '3.A.1.2.7|[beta-D-ribopyranose,mannose,fructose]'
#  '2.A.40.3.4|[7,9-dihydro-1H-purine-2,6,8(3H)-trione,7,9-dihydro-1H-purine-2,6,8(3H)-trione]'
#  '1.A.1.24.4|[potassium(1+)]' '1.A.23.3.2|[chloride,sodium(1+),molecule]'
#  '3.A.1.5.12|[rhamnose]' '3.A.1.2.33|[xylose]' '1.A.23.2.1|[ion]'
#  '2.A.1.2.97|[ciprofloxacin,drug]'
#  '2.A.56.1.10|[cinnamate,ferulate,trans-2-coumaricacid,cis-caffeicacid]'
#  '3.A.1.2.31|[purine]' '2.A.6.2.27|[triclosan]'
#  '2.A.102.4.5|[sulfurousacid]' '3.A.1.2.17|[nucleoside]'
#  '1.C.113.1.10|[furfural]'
#  '2.A.4.1.3|[cadmium(2+),zinc(2+),potassium(1+),hydron]'
#  '4.D.3.1.1|[D-glucosylgroup]' '3.A.1.20.4|[glycerol1-phosphodiester(1-)]'
#  '3.A.1.5.27|[glutathione]' '3.A.1.5.20|[oligopeptide]'
#  '2.A.6.2.33|[3,6-diamino-10-methylacridiniumchloride,ethidiumbromide,chloramphenicol,tetracycline,fluoroquinoloneantibiotic,macrolide,erythromycinA]'
#  '2.A.56.1.4|[taurine]' '2.A.7.3.54|[riboflavin]' '2.A.66.1.29|[drug]'
#  '2.A.80.1.3|[tricarboxylicacidtrianion]'
#  '3.A.1.4.5|[urea,hydroxyurea,thiourea]' '3.A.1.4.4|[urea]'
#  '3.A.1.201.8|[aluminium(3+)]' '3.A.1.5.17|[L-prolinebetaine]'
#  '2.A.4.7.7|[manganese(2+),hydron]' '1.A.26.1.7|[cobalt(2+),iron(2+)]'
#  '2.A.47.4.6|[sulfate,vanadiumoxoanion,molybdate,tungstate]'
#  '2.A.86.1.4|[autoinducer-2]' '2.A.47.4.2|[antimonite]'
#  '2.A.75.1.4|[L-canavanine]'
#  '2.A.15.1.5|[sodium(1+),L-prolinebetaine,glycinebetaine]'
#  '3.A.1.125.1|[lipoprotein]' '2.A.66.1.9|[polymyxinB1,norfloxacin]'
#  '2.A.7.3.3|[indigoidine]' '2.A.56.1.7|[malonateester]'
#  '2.A.15.1.1|[sodium(1+),glycinebetaine,S,S-dimethyl-beta-propiothetin,(carboxymethyl)(dimethyl)sulfonium]'
#  '3.A.3.5.39|[cadmium(2+),copper(1+),zincion]' '9.B.27.1.2|[selenite(2-)]'
#  '3.A.1.11.3|[mannopine]' '3.A.1.2.18|[xylose]'
#  '2.A.1.2.25|[fludarabinephosphate,adenine,adenosine,guanine,guanosine,inosine,hypoxanthine]'
#  '3.A.1.3.1|[lysine,ornithine,arginine,histidine]'
#  '3.A.1.3.11|[ornithine,arginine]' '3.A.5.1.1|[proteinpolypeptidechain]'
#  '2.A.7.3.7|[S-adenosyl-L-homocysteine,S-adenosyl-L-methionine]'
#  '2.A.38.1.2|[potassium(1+)]' '3.D.4.6.1|[hydron]'
#  '2.A.69.3.6|[malonateester]' '3.A.1.11.1|[spermidine,putrescine]'
#  '3.A.1.11.2|[putrescine]' '9.A.69.1.1|[phospholipid]'
#  '3.D.4.3.4|[hydron]' '1.A.30.2.9|[hydron]' '3.A.1.1.5|[hexitol]'
#  '3.A.1.4.15|[benzoate,hydratropicacid]' '3.A.1.15.5|[zinc(2+)]'
#  '3.A.1.27.3|[phospholipid,tetracycline,drug]' '2.A.21.9.2|[proline]'
#  '9.B.102.5.2|[Undecylprodigiosin]' '1.A.30.2.6|[hydron]'
#  '3.A.1.16.2|[nitrite,cyanate]'
#  '2.A.1.2.7|[3,6-diamino-10-methylacridiniumchloride,L-cysteine,sulfathiazole,fosfomycin,tetracycline,bicozamycin]'
#  '2.A.102.4.13|[acetate]' '2.A.7.7.2|[chloramphenicol]'
#  '3.A.1.210.15|[poly(sulfide)macromolecule]' '2.A.6.2.30|[ethidium,drug]'
#  '2.A.6.4.1|[hydron,proteinpolypeptidechain]'
#  '2.A.102.2.2|[sulfoaceticacid]' '3.A.1.107.1|[heme,ferrohemeb]'
#  '9.B.14.2.1|[ferrohemeb]'
#  '2.A.73.1.1|[butyrate,valericacid,short-chainfattyacid]'
#  '2.A.1.3.66|[drug]'
#  '2.A.56.1.9|[D-fuconate,D-galactonate,D-gluconate,D-xylonicacid]'
#  '2.A.56.1.1|[hydron,mesaconate(2-),itaconate(2-),malate(2-),succinate(2-),fumarate(2-),orotate]'
#  '2.A.7.3.56|[riboflavin]' '3.A.1.152.3|[lipopolysaccharide]'
#  '3.A.3.27.1|[cation]' '3.D.4.3.3|[hydron,proton]'
#  '3.A.1.11.9|[spermidine,putrescine,double-strandedDNA]'
#  '2.A.76.1.5|[L-norleucine,D-valine,L-methionine,L-valine,L-histidine,leucine]'
#  '3.A.1.9.1|[iron(3+)]' '3.A.1.9.3|[phosphite(3-)]'
#  '3.A.1.17.2|[sulfonate]' '2.A.28.2.4|[sodium(1+),bileacid]'
#  '2.A.53.3.9|[sulfate]' '5.A.1.2.7|[electron]' '2.A.51.1.4|[chromate(2-)]'
#  '3.A.1.5.4|[agrocinopine]'
#  '3.A.1.4.2|[glycine,alanine,proline,serine,histidine,leucine]'
#  '2.A.38.1.3|[potassium(1+)]' '1.A.11.1.4|[ammonia]'
#  '9.B.149.2.3|[protein]' '1.A.112.2.7|[magnesium(2+),cobalt(2+)]'
#  '2.A.1.81.1|[copper(2+)]'
#  '2.A.56.1.6|[sodium(1+),N-acetyl-beta-neuraminicacid]'
#  '2.A.76.1.2|[hydron,L-threonine]'
#  '3.A.11.1.3|[single-strandedDNApolynucleotide]'
#  '4.B.1.1.4|[thiamine(1+)]' '2.A.64.1.5|[protein]' '3.D.1.2.1|[hydron]'
#  '3.D.2.1.1|[hydron]' '2.A.49.6.4|[chloride,hydron]'
#  '2.A.103.1.3|[alpha-D-FucNAc4-(1->4)-beta-D-ManNAcA-(1->4)-D-GlcNAc-undecaprenyldiphosphate(3-)]'
#  '3.A.1.2.21|[myo-inositol]' '3.A.1.106.9|[actinorhodin]'
#  '3.A.7.2.1|[proteinpolypeptidechain]' '3.A.1.8.1|[molybdate]'
#  '3.D.4.6.2|[hydron]' '3.A.7.18.2|[protein]'
#  '1.A.30.2.2|[sodium(1+),hydron]' '2.A.66.1.55|[norfloxacin,xenobiotic]'
#  '2.A.39.3.4|[allantoin]' '2.A.1.60.3|[tetracycline,quinolone]'
#  '2.A.1.2.102|[Fusaricacid,tetracycline]' '2.A.66.1.36|[drug]'
#  '9.A.76.1.10|[fattyacid]' '2.A.7.3.48|[drug]' '1.A.30.4.3|[hydron]'
#  '2.A.78.2.1|[branched-chainaminoacid]' '5.A.1.5.2|[electron]'
#  '2.A.6.2.14|[chloramphenicol,tetracycline,aminocyclitolglycoside,diterpene]'
#  '2.A.76.1.10|[homoserine,L-threonine,serine,homoserinelactone]'
#  '9.B.31.1.1|[sn-glycerol3-phosphate]' '4.F.1.1.8|[phosphate(3-)]'
#  '2.A.19.5.2|[calcium(2+),sodium(1+),hydron]'
#  '3.A.1.105.17|[phospholipid,polyketide]'
#  '2.A.1.3.5|[hydron,pristinamycinIA,pristinamycinIIA,rifamycinSV]'
#  '9.B.27.1.1|[selenite(2-)]' '2.A.9.3.7|[proteinpolypeptidechain]'
#  '3.A.1.3.7|[glutamate(2-),aspartate(2-),asparagine,glutamine]'
#  '2.A.20.2.9|[phosphate(3-)]' '1.A.62.2.4|[calcium(2+)]'
#  '3.A.2.1.7|[hydron]' '1.A.77.2.7|[cation]' '1.A.1.14.4|[sodium(1+)]'
#  '3.A.1.5.49|[peptide]' '5.B.7.1.1|[electron]' '3.A.1.10.2|[iron(3+)]'
#  '3.A.1.4.10|[L-threonine,L-isoleucine,alanine,serine,leucine,valine]'
#  '3.A.1.4.1|[L-isoleucine,leucine,valine,phenylalanine,tyrosine]'
#  '2.A.113.1.7|[nickel(2+)]' '2.A.1.3.48|[ciprofloxacin,norfloxacin,drug]'
#  '2.A.2.3.12|[UDP-sugar]' '2.A.40.2.1|[7H-purine]'
#  '3.A.1.15.8|[iron(2+),manganese(2+),zinc(2+)]'
#  '2.A.25.1.3|[sodium(1+),alanine]' '9.B.450.1.1|[fattyacid,alkane]'
#  '3.D.3.1.1|[hydron]'
#  '3.A.1.19.1|[thiamine(1+)monophosphate,thiamine(1+)diphosphate,thiamine(1+)]'
#  '3.A.1.101.2|[polysaccharide]' '1.A.16.4.1|[anion,surfactant]'
#  '2.A.76.1.11|[alpha-aminoacid]' '1.A.10.2.3|[ion]'
#  '3.A.1.11.6|[gamma-aminobutyricacid]'
#  '2.A.1.13.17|[monocarboxylicacidanion,cephradine]'
#  '2.A.69.3.2|[malate(2-)]' '2.A.89.2.2|[iron(2+)]'
#  '2.A.56.1.17|[2-oxoglutarate(2-)]'
#  '1.A.23.1.1|[ion,chloride,potassium(1+),water]'
#  '1.A.11.2.3|[ammonia,methylamine]' '1.A.35.4.1|[cadmium(2+),zinc(2+)]'
#  '5.A.3.11.2|[electron]' '3.A.1.17.4|[taurine]'
#  '2.A.76.1.4|[azaserine,cysteine]' '1.A.22.1.4|[ion]'
#  '3.A.1.14.9|[corrinoid]' '3.A.1.1.7|[alpha,alpha-trehalose,maltose]'
#  '3.A.1.1.33|[N-acetyl-beta-D-glucosaminyl-(1->4)-N-acetyl-aldehydo-D-glucosamine]'
#  '3.A.1.2.16|[erythritol]' '2.A.3.3.16|[alpha-aminoacid]'
#  '3.D.4.4.3|[hydron]'
#  '2.A.56.3.2|[3-hydroxybenzoate,4-hydroxybenzoate,3-chlorobenzoate,4-chlorobenzoate,2-chlorobenzoate,4-fluorobenzoate,benzoate]'
#  '2.A.56.1.18|[2-oxoglutarate(2-),(S)-malate(2-),succinate(2-),fumarate(2-)]'
#  '3.A.1.1.3|[glycerol1-phosphate]' '3.A.1.1.50|[cholinealfoscerate]'
#  '3.A.7.11.1|[deoxyribonucleicacid]' '3.A.1.5.38|[L-alanyl-L-alanine]'
#  '3.D.4.10.1|[hydron]' '2.A.56.1.8|[N-acetyl-beta-neuraminicacid]'
#  '2.A.15.1.14|[trimethylamine]' '3.A.1.14.6|[ferrienterobactin(3-)]'
#  '3.A.1.14.2|[ferrienterobactin(3-)]'
#  "3.A.1.106.2|[tetraphenylphosphonium,verapamil,2'-(4-ethoxyphenyl)-5-(4-methylpiperazin-1-yl)-2,5'-bibenzimidazole,vincaleukoblastine,doxorubicin,ethidium]"
#  '3.A.1.3.10|[7,8-diaminononanoicacid,cystine]'
#  '3.A.1.3.24|[alpha-aminoacid]' '3.A.1.6.4|[vanadiumoxoanion]'
#  '5.A.3.2.1|[electron]'
#  '3.A.1.1.51|[alpha,alpha-trehalose,alpha-cyclodextrin,maltoheptaoseheptasaccharide,maltose,alpha-maltotriose,maltotetraose,maltopentaosepentasaccharide]'
#  '3.A.1.1.37|[arabinoside]' '9.B.43.1.1|[electron]'
#  '2.A.36.6.6|[sodium(1+),hydron]' '3.A.1.17.3|[pyrimidine]'
#  '3.A.1.9.2|[phosphonate(2-),phosphate(3-),phosphite(3-)]'
#  '3.A.1.9.4|[phosphinate,phosphonate(2-),phosphite(3-)]'
#  '2.A.1.30.3|[enterobactin]' '2.A.36.6.1|[sodium(1+)]'
#  '2.A.53.1.14|[sulfate]' '2.A.6.2.3|[isoflavonoid]'
#  '3.A.1.1.35|[glycerol]' '2.A.56.1.12|[2-oxoglutaricacid]'
#  '2.A.38.4.3|[potassium(1+)]'
#  '2.A.59.1.3|[arsenate(3-),arsenicmolecularentity]'
#  '3.A.1.7.6|[triphosphate(5-)]' '2.A.53.3.1|[sulfate]'
#  '3.A.1.17.8|[thiamine(1+)]' '9.A.47.1.1|[proteinpolypeptidechain]'
#  '3.A.1.109.4|[ciprofloxacin,gentamycin,tobramycin]'
#  '2.A.63.1.1|[sodium(1+),potassium(1+),hydron]'
#  '2.A.63.1.4|[sodium(1+),hydron]' '3.A.1.5.19|[oligopeptide]'
#  '2.A.80.1.2|[terephthalate(2-),isophthalate(2-),(3,4-dihydroxyphenyl)acetate,dibutylphthalate]'
#  '3.A.1.3.15|[arginine]'
#  '3.A.1.3.12|[lysine,arginine,glutamine,histidine]'
#  '3.A.7.1.1|[proteinpolypeptidechain]' '3.A.7.3.1|[toxin]'
#  '3.A.1.14.16|[ferrohemeb]' '3.A.1.14.8|[iron(III)vibrioferrin]'
#  '3.A.1.110.3|[proteinpolypeptidechain]'
#  '3.A.1.4.7|[(3,4-dihydroxyphenyl)acetate]' '2.A.1.31.8|[nickel(2+)]'
#  '2.A.6.2.38|[detergent]' '3.A.7.5.1|[proteinpolypeptidechain]'
#  '3.A.1.20.1|[iron(3+)]' '2.A.1.70.9|[arsenite(3-),antimonite,roxarsone]'
#  '3.A.1.4.8|[L-threonine,L-isoleucine,alanine,serine,leucine,valine]'
#  "3.A.1.106.18|[2'-(4-ethoxyphenyl)-5-(4-methylpiperazin-1-yl)-2,5'-bibenzimidazole]"
#  '2.A.69.3.4|[malonateester]' '2.A.58.2.1|[phosphate(3-)]'
#  '3.A.1.12.1|[4-(trimethylammonio)butanoate,choline,carnitinium,beta-alaninebetaine,glycinebetaine,proline]'
#  '1.A.77.2.16|[magnesium(2+)]' '2.A.9.3.1|[proteinpolypeptidechain]'
#  '3.A.3.5.34|[copper(1+)]' '3.A.3.6.25|[cadmium(2+),cobalt(2+),zinc(2+)]'
#  '2.A.46.1.9|[benzoate]' '1.A.11.2.5|[ammonium,tetramethylammonium]'
#  '2.A.7.3.67|[alpha-aminoacid]' '4.F.1.3.1|[phosphate(3-)]'
#  '3.A.1.1.58|[N-acetyl-beta-D-glucosamine]' '3.A.1.6.2|[tungstate]'
#  '2.A.2.3.2|[pentoside]'
#  '3.A.1.1.25|[alpha,alpha-trehalose,maltose,sucrose,6-O-alpha-D-glucopyranosyl-D-fructofuranose]'
#  "3.A.1.2.10|[adenosine,guanosine,2'-deoxyguanosine,inosine,xanthosine]"
#  '3.A.1.14.23|[cyanocob(III)alamin,cobalamin]' '2.A.66.4.3|[glutamine]'
#  '3.A.1.3.17|[lysine,arginine,histidine]' '2.A.7.3.55|[riboflavin]'
#  '3.A.5.1.3|[proteinpolypeptidechain]' '1.A.46.2.5|[anion]'
#  '2.A.35.1.1|[sodium(1+),hydron]' '9.A.5.1.1|[arginine]'
#  '3.A.7.6.1|[proteinpolypeptidechain]' '3.D.4.2.1|[hydron,dioxygen]'
#  '1.A.16.3.4|[nitrate]' '3.A.1.3.18|[alpha-aminoacid]'
#  '2.A.15.1.13|[proline]'
#  '2.A.1.20.1|[streptomycin,kanamycin,isopropylbeta-D-thiogalactopyranoside,oligosaccharide,beta-D-Gal-(1->3)-beta-D-GlcNAc-(1->3)-beta-D-Gal-(1->4)-D-Glc,maltose,cellobiose,alpha-lactose,methylalpha-D-glucopyranoside,galactoside,glucose]'
#  '9.A.76.1.8|[fattyacid]' '3.A.1.14.21|[ferrohemeb]'
#  '3.A.1.1.41|[alpha,alpha-trehalose]' '3.A.1.7.3|[phosphate(3-)]'
#  '2.A.7.1.11|[benzalkoniumchloride,3,6-diamino-10-methylacridiniumchloride,ethidiumbromide,sodiumdodecylsulfate,deoxycholate,thiamine(1+)diphosphate,acridineorangefreebase,chloramphenicol,novobiocin,nifedipine,erythromycinA]'
#  '1.A.8.12.10|[arsenite(3-)]' '2.A.66.1.25|[drug]'
#  '2.A.1.2.39|[tetracycline]' '9.A.69.1.2|[phospholipid]'
#  '3.B.1.1.5|[sodium(1+)]'
#  '3.A.1.1.8|[alpha,alpha-trehalose,maltose,sucrose]'
#  '3.A.1.1.57|[oligosaccharide]' '3.A.1.1.30|[glucose]'
#  '2.A.98.1.2|[sulfate]' '3.A.1.5.3|[nickel(2+)]'
#  '2.A.27.1.2|[sodium(1+),glutamate(2-)]' '2.A.53.3.13|[fumarate(2-)]'
#  '1.A.30.2.7|[hydron]' '3.A.1.2.12|[deoxyribonucleoside]'
#  '2.A.7.3.66|[alpha-aminoacid]'
#  '2.A.15.1.6|[sodium(1+),glycinebetaine,S,S-dimethyl-beta-propiothetin]'
#  '2.A.7.3.58|[glutamate(2-),aspartate(2-),glutamine]'
#  '3.A.1.15.21|[manganese(2+)]' '3.A.6.2.1|[protein]'
#  '1.A.30.1.1|[hydron,proton]' '1.A.104.1.3|[sodium(1+),hydron]'
#  '3.A.6.1.1|[proteinpolypeptidechain]' '2.A.102.3.4|[glycine]'
#  '2.A.66.2.6|[teichuronicacid]' '3.A.1.2.32|[arabinose]'
#  '9.B.20.2.2|[magnesium(2+)]'
#  '2.A.47.1.13|[sodium(1+),dicarboxylicaciddianion,oxaloacetate(2-),2-oxoglutarate(2-),malate(2-),succinate(2-),fumarate(2-)]'
#  '3.A.1.5.16|[beta-glucoside]'
#  '3.A.1.5.2|[dipeptide,5-aminolevulinicacid,ferrohemeb]'
#  "3.A.1.109.3|[2'-(4-ethoxyphenyl)-5-(4-methylpiperazin-1-yl)-2,5'-bibenzimidazole]"
#  '3.A.1.14.19|[ferrohemeb]' '2.A.15.1.11|[sodium(1+),glycinebetaine]'
#  '3.A.1.17.10|[sulfonate]' '3.A.1.3.5|[D-octopine]'
#  '1.A.72.3.6|[mercury(2+)]' '1.A.72.1.1|[mercury(2+)]'
#  '2.A.4.4.7|[lead(2+)]' '2.A.5.5.10|[iron(2+),zinc(2+)]'
#  '3.A.1.123.2|[bacteriocin]' '2.A.1.43.2|[iron(2+)]'
#  '5.A.1.5.1|[electron]' '2.A.80.1.4|[citratesalt]'
#  '2.A.1.49.10|[ethidiumbromide,capreomycin]'
#  '2.A.7.3.2|[cysteine,asparagine,glutamine]'
#  '3.A.1.13.1|[cyanocob(III)alamin]'
#  '2.A.25.1.9|[glycine,alanine,asparagine,glutamine]'
#  '9.A.2.1.2|[hydrogencarbonate,carbondioxide]' '3.A.1.2.15|[xylitol]'
#  '3.A.1.2.27|[UDP-sugar]' '3.A.7.4.2|[proteinpolypeptidechain]'
#  '3.A.1.101.1|[[3)-beta-D-galactopyranuronosyl-(1->3)-2-acetamido-4-amino-2,4,6-trideoxy-alpha-D-glucopyranosyl-(1->4)-beta-D-galactopyranurosyl-(1->]n]'
#  '9.B.62.3.2|[copper(2+)]' '2.A.59.2.1|[arsenite(3-)]'
#  '2.A.4.1.1|[cadmium(2+),cobalt(2+),copper(2+),nickel(2+),zinc(2+)]'
#  '2.A.6.1.2|[cadmium(2+),cobalt(2+),zinc(2+)]'
#  '2.A.6.1.13|[cadmium(2+),zinc(2+)]' '1.A.72.3.1|[mercury(2+)]'
#  '2.A.122.1.1|[3-hydroxypropionate]' '5.A.2.1.1|[electron]'
#  '2.A.36.6.4|[potassium(1+),hydron,ammonium]' '1.A.1.13.4|[potassium(1+)]'
#  '2.A.103.1.1|[alpha-D-FucNAc4-(1->4)-beta-D-ManNAcA-(1->4)-D-GlcNAc-undecaprenyldiphosphate(3-)]'
#  '2.A.6.7.6|[lipid]' '9.B.391.1.2|[protein]'
#  '3.A.1.14.3|[iron(III)hydroxamate,elaiophylin]' '3.A.1.106.14|[lipidAs]'
#  '2.A.22.5.3|[sodium(1+),neurotransmitter]'
#  '2.A.75.1.2|[lysine,arginine,histidine]'
#  '2.A.6.2.16|[chloramphenicol,acrolein,fluoroquinoloneantibiotic]'
#  '2.A.89.3.8|[iron(2+),manganese(2+)]'
#  '3.A.1.12.15|[choline,glycinebetaine,glycine]' '2.A.46.1.8|[benzoate]'
#  '2.A.76.1.8|[alpha-aminoacid]' '9.B.104.1.1|[proteinpolypeptidechain]'
#  '1.C.53.1.5|[ion]' '2.A.46.1.7|[benzoate]'
#  '2.A.6.2.17|[chloramphenicol,acrolein,tetracycline,triclosan,fluoroquinoloneantibiotic,macrolide,erythromycinA]'
#  '2.A.21.7.5|[acetate,tellurite]' '3.D.6.1.1|[hydron]'
#  '3.D.6.1.4|[hydron]' '4.F.1.1.7|[phosphate(3-)]'
#  '3.A.1.152.1|[lipopolysaccharide]' '3.B.1.1.6|[sodium(1+)]'
#  '3.B.1.1.1|[sodium(1+)]' '3.A.1.6.1|[sulfate,thiosulfate(2-)]'
#  '2.A.1.6.4|[sodium(1+),hydron,L-prolinebetaine,carnitinium,glycinebetaine,N,N-dimethylglycine,proline,taurine,pipecolicacid,ectoine,3-pyridylaceticacid]'
#  '2.A.5.5.12|[iron(2+),zinc(2+)]'
#  '2.A.4.7.9|[cadmium(2+),cobalt(2+),iron(2+),nickel(2+),zinc(2+)]'
#  '3.A.1.3.2|[glutamine]' '3.A.1.3.21|[trans-4-hydroxy-L-proline]'
#  '3.A.1.34.1|[tryptophan]' '3.D.10.1.6|[hydron]'
#  '2.A.78.1.1|[branched-chainaminoacid]'
#  '3.A.1.27.1|[gamma-hexachlorocyclohexane]' '3.A.15.1.1|[protein]'
#  '2.A.28.3.4|[sodium(1+)]'
#  '9.A.2.1.1|[hydrogencarbonate,carbonicacid,carbondioxide]'
#  '3.A.1.129.1|[glutathione,cysteine]' '3.A.1.5.24|[peptide]'
#  '2.A.1.65.9|[maltose]' '1.A.30.3.1|[hydron]' '9.B.297.4.4|[protein]'
#  '2.A.66.2.23|[polysaccharide]' '4.D.2.1.6|[glycosylgroup]'
#  '3.A.1.106.20|[phospholipid,lipidAs,lipopolysaccharide,drug]'
#  '3.A.11.2.3|[single-strandedDNApolynucleotide]'
#  '9.B.1.1.6|[proteinpolypeptidechain]' '5.A.1.1.1|[electron]'
#  '3.A.3.27.5|[copper(1+)]' '5.A.1.6.1|[electron]'
#  '2.A.47.1.12|[dicarboxylicaciddianion,malate(2-),succinate(2-),fumarate(2-)]'
#  '2.A.21.6.5|[sodium(1+)]'
#  '3.A.1.3.26|[L-threonine,asparagine,glutamine,serine,histidine,tyrosine]'
#  '2.A.21.2.5|[proline]' '3.D.5.1.1|[sodium(1+)]' '9.B.14.2.4|[ferrohemeb]'
#  '3.A.1.107.4|[apocytochromec,heme]' '1.A.30.1.5|[hydron]'
#  '1.A.104.1.4|[hydron]' '2.A.40.1.4|[uracil]'
#  '2.A.1.25.2|[peptide,glycopeptide]' '1.A.54.5.3|[cation]'
#  '9.B.157.1.3|[folicacid]' '8.A.21.2.10|[alanine]'
#  '1.A.30.1.7|[sodium(1+),proton]' '2.A.47.4.5|[sodium(1+),sulfate]'
#  '2.A.40.7.6|[adenine]' '1.A.23.4.1|[ion]' '9.B.334.1.3|[electron]'
#  '1.A.112.2.13|[magnesium(2+),cobalt(2+)]'
#  '2.A.63.1.2|[sodium(1+),hydron]'
#  '2.A.23.1.5|[anion,glutamate(2-),aspartate(2-)]' '1.A.23.7.1|[ion]'
#  '2.A.39.1.1|[cytosine]' '9.B.20.1.3|[magnesium(2+)]'
#  '2.A.58.2.4|[sodium(1+),phosphate(3-)]' '2.A.99.1.2|[nickel(2+)]'
#  '1.C.113.1.1|[molecule]' '1.A.1.14.8|[sodium(1+)]'
#  '2.A.62.1.5|[lithium(1+),sodium(1+)]' '2.A.51.1.7|[chromate(2-)]'
#  '3.A.1.17.1|[taurine]' '3.A.1.105.11|[lantibiotic]'
#  '3.A.1.17.5|[phthalate(2-)]' '1.A.1.23.4|[ion]'
#  '3.A.1.12.6|[L-prolinebetaine,glycinebetaine,proline,histidine]'
#  '3.A.1.8.3|[molybdate]' '3.A.3.2.29|[calcium(2+)]'
#  '1.A.43.1.1|[fluoride,chloride]' '2.A.121.1.4|[sulfate]'
#  '2.A.59.1.6|[arsenite(3-)]' '1.E.43.1.14|[proteinpolypeptidechain]'
#  '3.A.23.1.1|[proteinpolypeptidechain,deoxyribonucleicacid]'
#  '2.A.56.2.1|[5-hydroxyectoine,ectoine]'
#  '3.A.3.5.5|[copper(1+),silver(1+)]' '3.A.1.14.11|[molybdate,tungstate]'
#  '2.A.95.1.7|[alpha-aminoacid]' '9.B.2.1.29|[protein]'
#  '2.A.34.1.3|[lithium(1+),sodium(1+),hydron]' '3.A.2.1.1|[hydron]'
#  '1.A.77.3.9|[cation]' '2.A.1.42.2|[monoacylglycerolphosphate]'
#  '3.A.1.210.9|[cobalt(2+),nickel(2+)]' '4.A.2.1.17|[fructose]'
#  '1.A.30.1.2|[sodium(1+)]' '1.A.30.1.6|[sodium(1+)]'
#  '2.A.8.1.12|[histidine]' '2.A.66.1.4|[bileacid]'
#  '2.A.1.17.3|[2-nitroimidazole]' '2.A.37.3.3|[sodium(1+),hydron]'
#  '2.A.1.3.62|[chloramphenicol,tetracycline]' '2.A.106.1.8|[lactate]'
#  '2.A.36.6.11|[sodium(1+)]' '2.A.21.3.5|[sodium(1+),myo-inositol]'
#  '1.A.16.2.3|[formate]' '3.A.1.24.5|[L-histidine]'
#  '2.A.66.1.1|[sodium(1+),norfloxacin,streptomycin,kanamycin,ethidium]'
#  '2.A.7.3.1|[acetate]'
#  '9.B.142.2.8|[lipopolysaccharide,4-amino-4-deoxy-L-arabinose]'
#  '2.A.118.1.2|[dicarboxylicaciddianion]' '1.A.77.2.9|[cation]'
#  '3.A.2.1.12|[sodium(1+)]' '2.A.6.3.13|[thiophosphate(2-)]'
#  '3.A.1.4.14|[methionine,leucine,valine,isoleucine,branched-chainaminoacid]'
#  '2.A.53.5.3|[molybdate]' '3.A.7.4.1|[proteinpolypeptidechain]'
#  '9.A.47.2.1|[proteinpolypeptidechain]' '2.A.66.2.2|[polysaccharide]'
#  '9.A.76.1.4|[oleicacid]' '3.A.1.17.6|[pyrimidine]'
#  '2.A.7.3.6|[homoserine,L-threonine]' '2.A.76.1.7|[alpha-aminoacid]'
#  '1.A.104.1.1|[sodium(1+)]' '1.A.23.1.5|[ion]' '3.D.3.1.2|[proton]'
#  '2.A.66.4.1|[keto-D-fructose6-phosphate]' '1.A.16.1.3|[formate]'
#  '2.A.102.4.8|[sulfate]' '3.A.1.5.29|[xylan]' '3.A.1.2.4|[xylose]'
#  '2.A.1.32.3|[copper(2+),drug]' '1.A.8.3.1|[water]'
#  '4.D.3.1.5|[(1->4)-beta-D-glucan]' '2.A.1.31.1|[nickel(2+)]'
#  '4.D.1.1.3|[UDP-N-acetyl-alpha-D-glucosamine,N-acetyl-beta-D-glucosamine]'
#  '3.A.1.12.12|[choline,carnitinium,glycinebetaine]'
#  '1.A.11.2.7|[ammonium,tetramethylammonium]' '2.A.71.2.4|[folicacid]'
#  '3.A.1.105.12|[phosphonate(2-)]' '2.A.21.7.4|[acetate,tellurite]'
#  '4.H.1.1.5|[3-O-L-alanyl-1-O-phosphatidylglycerolzwitterion]'
#  '3.A.1.4.6|[alpha-aminoacidzwitterion]'
#  '3.A.11.1.1|[single-strandedDNApolynucleotide]'
#  '3.A.1.3.8|[alpha-aminoacid]'
#  '2.A.1.2.3|[hydron,chloramphenicol,arabinose]' '3.A.1.2.11|[erythritol]'
#  '2.A.56.1.2|[2,3-diketogulonate]'
#  '3.A.1.3.22|[N-acetyl-L-glutamicacid,glutamicacid,glutamine]'
#  '3.A.1.3.19|[glutamate(2-),aspartate(2-),asparagine,glutamine]'
#  '3.A.1.3.4|[glutamate(2-)]' '9.B.69.1.1|[cobalt(2+)]' '2.A.1.26.2|[drug]'
#  '3.A.1.4.12|[2-oxopentanoate,pyruvate,2-oxobutanoate,3-methyl-2-oxovalerate]'
#  '2.A.123.2.14|[sucrose]' '2.A.46.1.4|[benzoate]' '2.A.69.3.1|[auxin]'
#  '1.B.76.1.8|[copper(2+)]' '1.B.42.1.2|[lipopolysaccharide]'
#  '1.A.43.1.7|[fluoride]' '1.A.43.1.6|[fluoride]'
#  '3.A.1.132.2|[copper(2+)]'
#  '3.A.1.4.3|[gamma-aminobutyricacid,alpha-aminoacid]'
#  '1.A.16.3.1|[nitrite]' '3.A.1.2.20|[xylose,glucose]'
#  "2.A.1.2.122|[1,1'-azobis(N,N-dimethylformamide)]"
#  '2.A.38.1.5|[lithium(1+),sodium(1+),potassium(1+),rubidium(1+)]'
#  '2.A.79.1.2|[L-threonine]' '3.A.1.10.6|[iron(3+)]'
#  '2.A.36.6.5|[sodium(1+),potassium(1+),hydron]'
#  '2.A.7.1.10|[benzalkoniumchloride,cetylpyridiniumchloride,ethidiumbromide,cetyltrimethylammoniumbromide,sodiumdodecylsulfate,thiamine(1+)diphosphate]'
#  '2.A.21.3.2|[sodium(1+),glucose,galactose]' '2.A.21.3.9|[galactose]'
#  '9.B.42.1.1|[proteinpolypeptidechain]'
#  '2.A.6.1.16|[cadmium(2+),cobalt(2+),nickel(2+),zinc(2+)]'
#  '2.A.1.7.12|[alpha,alpha-trehalose]' '2.A.1.10.3|[D-glucosylgroup]'
#  '2.A.36.6.3|[potassium(1+)]' '2.A.6.2.37|[detergent]'
#  '2.A.33.1.2|[sodium(1+),potassium(1+),hydron]'
#  '2.A.35.2.1|[sodium(1+),hydron]' '2.A.55.3.4|[metalcation]'
#  '2.A.5.5.6|[cadmium(2+),magnesium(2+),cobalt(2+),copper(2+),iron(2+),nickel(2+),zinc(2+)]'
#  '1.A.1.14.3|[sodium(1+)]' '2.A.46.1.1|[benzoate]'
#  '2.A.6.4.3|[proton,proteinpolypeptidechain]'
#  '2.A.6.2.44|[safraninO,ethidiumbromide,clindamycin,acridineorangefreebase,trimethoprim,sulfanilamide,sulfamethoxazole,chloramphenicol,fluoroquinoloneantibiotic]'
#  '2.A.20.2.4|[phosphate(3-)]' '2.A.6.3.7|[copper(2+)]'
#  '3.A.1.115.1|[sodium(1+)]' '3.A.1.107.3|[ferrohemeb]'
#  '9.B.14.2.3|[ferrohemeb]' '2.A.17.1.7|[peptide]'
#  '2.A.37.1.3|[potassium(1+)]' '2.A.53.3.3|[sodium(1+),hydrogencarbonate]'
#  '3.A.1.5.42|[peptide]' '1.A.30.3.3|[hydron]' '2.A.21.2.4|[proline]'
#  '9.B.14.3.6|[magnesium(2+)]' '3.A.1.201.30|[acaricide,drug]'
#  '1.A.62.2.2|[long-chainfattyacid]' '2.C.1.2.1|[phospholipid]'
#  '2.A.6.3.15|[drug]' '3.A.1.14.25|[ferrohemeb]'
#  '2.A.8.1.13|[propionate,butyrate,(S)-2-hydroxybutyricacid]'
#  '2.A.25.1.10|[glycine,alanine]'
#  '2.A.23.1.1|[glutamate(2-),aspartate(2-)]' '2.A.40.4.2|[9H-xanthine]'
#  '9.B.97.5.4|[acyl-CoA]' '2.A.1.2.99|[siderophore]'
#  '2.A.35.1.9|[L-methionine]' '2.A.39.5.1|[D-mannitol]'
#  '3.A.1.19.4|[sulfate,thiosulfate(2-)]' '3.A.1.132.11|[siderophore]'
#  '2.A.15.1.9|[glycinebetaine]' '2.A.1.11.3|[pyruvate]'
#  '3.A.1.106.1|[phospholipid,lipidAs,lipopolysaccharide,drug]'
#  '2.A.2.6.3|[maltose]' '2.A.127.1.1|[cardiolipin]'
#  '2.A.22.5.5|[hypotaurine]'
#  '2.A.35.1.2|[sodium(1+),hydron,malate(2-),lactate]'
#  '2.A.46.1.11|[7H-purine,adenosine,guanosine]' '1.A.43.1.11|[fluoride]'
#  '2.A.6.3.14|[ethidiumbromide,sodiumdodecylsulfate,ciprofloxacin,ampicillin,cefoperazone,cefoxitin,imipenem,metronidazole]'
#  '3.A.1.8.4|[sodiumtungstate,molybdate]'
#  '2.A.25.1.1|[sodium(1+),glycine,alanine]' '2.A.47.1.1|[anion]'
#  '2.A.34.1.2|[sodium(1+),potassium(1+),hydron]' '4.C.1.1.4|[fattyacid]'
#  '2.A.14.2.2|[lactate]' '9.B.391.1.3|[protein]'
#  '1.A.1.13.2|[potassium(1+)]' '2.A.66.2.7|[lipopolysaccharide]'
#  '2.A.1.20.2|[oligosaccharide,beta-D-Gal-(1->3)-beta-D-GlcNAc-(1->3)-beta-D-Gal-(1->4)-D-Glc,alpha-lactose,trisaccharide,glucose]'
#  '2.A.1.7.9|[N-acetylgalactosamine]' '2.A.6.1.4|[copper(1+),silver(1+)]'
#  '9.A.4.1.1|[potassium(1+)]' '2.A.78.1.3|[methionine]'
#  '9.B.238.3.5|[proteinpolypeptidechain,ATP]'
#  '8.A.213.1.1|[silver(1+),gold(1+),ceftazidime,drug]'
#  '2.A.1.3.26|[deoxycholate,novobiocin,arabinose]'
#  '2.A.21.5.1|[bromide,iodide,bromate,iodate,isothiocyanatogroup,nitricacid]'
#  '2.A.62.1.2|[lithium(1+),sodium(1+),hydron]'
#  '2.A.1.7.1|[hydron,L-fucopyranose]' '2.A.49.5.5|[chloride,hydron]'
#  '2.A.55.3.1|[cadmium(2+),cobalt(2+),iron(2+),manganese(2+),nickel(2+),zinc(2+)]'
#  '8.A.21.2.6|[protein]' '2.A.4.8.1|[metalcation]'
#  '1.A.8.1.1|[arsenite(3-),polyol,glycerol]' '2.A.107.1.1|[manganese(2+)]'
#  '1.A.23.4.5|[ion,molecule]'
#  '2.A.3.8.12|[L-threonine,serine,histidine,phenylalanine,tryptophan,tyrosine]'
#  '2.A.39.3.14|[allantoin,adenine,guanine,uracil]' '2.A.8.1.8|[gluconate]'
#  '2.A.41.2.11|[nucleoside]' '2.A.58.1.2|[sodium(1+),phosphate(3-)]'
#  '3.A.1.212.1|[peptide]' '2.A.95.1.5|[antimicrobialagent]'
#  '1.A.112.2.10|[magnesium(2+)]'
#  '2.A.119.1.6|[cadmium(2+),copper(2+),zinc(2+)]' '5.B.10.1.1|[iron(3+)]'
#  '1.A.30.2.3|[hydron]' '2.A.1.7.6|[sucrose]' '2.A.68.1.2|[drug]'
#  '2.A.102.2.1|[3-sulfonatolactate(2-)]'
#  '2.A.21.3.21|[sodium(1+),UDP-sugar]' '2.A.4.1.7|[zinc(2+)]'
#  '2.A.1.7.2|[glucose,galactose]' '2.A.1.1.81|[glucose]'
#  '2.A.1.32.2|[corynebactin]' '3.D.2.2.1|[hydron]' '3.D.2.2.2|[hydron]'
#  '3.D.4.5.1|[hydron]' '1.A.1.24.1|[potassium(1+)]'
#  '2.A.1.7.3|[proton,xylose,glucose,mannose]' '3.D.4.7.1|[hydron]'
#  '1.A.77.3.7|[cation]' '1.A.72.4.1|[mercury(2+)]'
#  '2.A.6.1.19|[cadmium(2+),cobalt(2+),zinc(2+)]'
#  '9.B.62.1.6|[coppercation]' '2.A.42.2.1|[serine]'
#  '2.A.1.36.1|[3,6-diamino-10-methylacridiniumchloride,arabinose]'
#  '2.A.4.7.5|[cadmium(2+),zinc(2+)]' '2.A.118.1.4|[fattyacid]'
#  '2.A.1.3.17|[trimethoprim]' '9.B.28.2.2|[maltose]' '1.A.10.2.2|[ion]'
#  '2.A.1.3.30|[lincomycin]' '1.A.78.2.9|[potassium(1+)]'
#  '2.A.55.2.5|[cadmium(2+),iron(2+),manganese(2+),zinc(2+)]'
#  '2.A.66.6.1|[exopolysaccharide]' '1.E.14.1.1|[metabolite]'
#  '2.A.68.1.5|[drug]' '2.A.85.1.4|[Fusaricacid]'
#  '2.A.1.2.15|[hydron,oligosaccharide,beta-D-Gal-(1->3)-beta-D-GlcNAc-(1->3)-beta-D-Gal-(1->4)-D-Glc,arabinose]'
#  '1.A.30.3.2|[hydron]'
#  '2.C.1.1.12|[beta-lactam,ceftazidime,fluoroquinoloneantibiotic]'
#  '2.A.35.1.5|[methionine]'
#  '1.A.26.1.2|[calcium(2+),magnesium(2+),manganese(2+)]'
#  '2.A.36.6.8|[sodium(1+),hydron]' '2.A.7.3.65|[riboflavin]'
#  '9.B.20.1.4|[magnesium(2+)]' '3.A.1.115.2|[sodiumatom]'
#  '9.B.164.1.2|[molecule]' '2.A.55.2.6|[manganese(2+)]'
#  '2.A.66.1.3|[deoxycholate,enoxacin,norfloxacin,trimethoprim,fosfomycin,chloramphenicol,doxorubicin,ethidium]'
#  '2.A.1.14.25|[D-mannuronate]' '2.A.66.5.3|[polysaccharide]'
#  '2.A.127.1.2|[cardiolipin]' '5.A.1.6.4|[electron]'
#  '2.A.23.2.11|[glutamate(2-),aspartate(2-)]' '2.A.117.1.4|[drug]'
#  '2.A.1.1.32|[glucose,fructose]'
#  '2.A.27.1.1|[glutamate(2-),D-glutamate(2-),L-glutamate(1-),L-homocysteinate]'
#  '2.A.42.1.1|[tyrosine]' '2.A.1.49.7|[sphingosine1-phosphate]'
#  '2.A.66.1.28|[drug]' '4.D.3.1.6|[(1->4)-beta-D-glucan]'
#  '2.A.1.2.22|[chloramphenicol,drug]' '3.D.4.10.5|[proton]'
#  '2.A.23.1.8|[cystine]' '2.A.53.4.2|[sulfate]'
#  '2.A.7.1.9|[sodiumdodecylsulfate,deoxycholate,spermidine]'
#  '1.A.23.4.12|[ion]' '9.B.121.2.4|[lipid]' '3.A.1.201.22|[doxorubicin]'
#  '2.A.37.1.2|[potassium(1+)]' '9.B.62.1.5|[copper(2+)]'
#  '2.A.117.1.2|[chlorhexidine]' '1.A.30.3.4|[hydron]'
#  '2.A.21.3.7|[N-acetyl-beta-neuraminicacid]'
#  '2.A.21.3.10|[N-acetyl-beta-neuraminicacid]'
#  '2.A.7.17.1|[phenylalanine,tryptophan,tyrosine]'
#  '2.A.4.1.4|[cadmium(2+),zinc(2+),hydron]'
#  '1.A.112.2.11|[putrescine,cadaverine]' '2.A.21.1.1|[pantothenate]'
#  '1.A.1.13.1|[potassium(1+)]' '1.A.30.2.11|[proton]'
#  '1.A.8.2.9|[glycerol]' '3.A.1.3.16|[glutamate(2-),aspartate(2-)]'
#  '3.A.1.5.34|[oligopeptide]'
#  '2.A.15.1.2|[sodium(1+),glycinebetaine,proline]' '9.A.76.1.9|[fattyacid]'
#  '2.A.21.3.22|[D-glucopyranose]' '3.D.4.4.1|[hydron]' '1.A.23.7.2|[ion]'
#  '4.D.3.1.11|[polysaccharide]' '1.A.1.14.2|[sodium(1+)]'
#  '2.A.36.4.5|[sodium(1+),hydron]' '1.A.43.1.5|[fluoride,(R)-camphor]'
#  '3.A.1.12.2|[glycinebetaine,S,S-dimethyl-beta-propiothetin,(carboxymethyl)(dimethyl)sulfonium]'
#  '2.A.76.1.3|[alpha-aminoacid]' '2.A.76.1.9|[L-homoserine,L-serine]'
#  '2.A.6.2.2|[phospholipid,bileacid,ethidium,steroidhormone,disinfectant,detergent,drug,dye]'
#  '2.A.99.1.3|[nickel(2+)]' '3.A.1.12.14|[glycinebetaine]'
#  '2.A.7.3.22|[methionine,alpha-aminoacid]' '3.A.1.5.22|[peptide]'
#  '2.A.95.1.4|[L-threonine,L-alanine,L-serine,glycine]'
#  '2.A.6.2.32|[fluoroquinoloneantibiotic]' '2.A.38.1.1|[potassium(1+)]'
#  '2.A.3.3.13|[alpha-aminoacid]'
#  '3.A.1.11.10|[polyaminemacromolecule,sym-homospermidine]'
#  '3.A.1.3.3|[arginine]' '2.A.28.2.6|[macrolide]' '3.A.1.105.15|[drug]'
#  '2.A.1.41.3|[bacteriochlorophyll]' '2.A.1.41.1|[biologicalpigment]'
#  '2.A.19.5.1|[calcium(2+)]' '9.A.24.1.2|[cholesterol,porphyrin]'
#  '3.A.3.6.23|[cadmium(2+),lead(2+),zinc(2+)]'
#  '3.A.3.6.12|[cadmium(2+),lead(2+),cobalt(2+),mercury(2+),nickel(2+),zinc(2+),hydron]'
#  '2.A.3.6.3|[alpha-aminoacid]' '2.A.46.1.2|[benzoate]'
#  '2.A.19.5.4|[calcium(2+),sodium(1+)]' '2.A.25.1.5|[alanine]'
#  '3.A.1.2.19|[beta-D-ribopyranose]' '2.A.33.1.3|[sodium(1+),hydron]'
#  '2.A.4.7.1|[cadmium(2+),iron(2+),mercury(2+),zinc(2+),hydron]'
#  '3.A.1.15.9|[iron(2+),manganese(2+)]' '3.A.3.6.26|[cadmium(2+),zinc(2+)]'
#  '3.A.5.1.4|[protein]' '2.A.1.8.8|[nitrite,nitrate]'
#  '4.D.1.1.9|[alginicacid]' '2.A.109.2.1|[telluriumatom]'
#  '4.C.1.1.7|[fattyacid]' '3.A.1.17.14|[riboflavin]'
#  '3.A.1.1.18|[N-acetyl-beta-D-glucosaminyl-(1->4)-N-acetyl-aldehydo-D-glucosamine,N-acetyl-beta-D-glucosamine]'
#  '3.A.1.5.1|[oligopeptide]' '3.A.1.5.41|[oligopeptide]'
#  '3.A.1.1.10|[alginicacid]' '2.A.98.1.1|[sulfate]' '3.A.1.12.7|[choline]'
#  '3.A.1.2.1|[beta-D-ribopyranose]' '3.A.1.2.13|[autoinducer-2]'
#  '2.A.33.1.1|[sodium(1+),proton]' '3.A.7.18.1|[toxin]'
#  '3.A.1.25.7|[riboflavin]' '3.A.1.1.4|[alpha-lactose]'
#  '1.C.107.1.4|[toxin]' '3.A.1.1.39|[alpha-D,alpha-D-digalacturonate]'
#  '3.A.1.1.17|[alpha,alpha-trehalose,maltose,sucrose]'
#  '2.A.53.3.11|[succinate(2-),fumarate(2-),aspartate(2-),hydrogencarbonate]'
#  '3.A.1.1.15|[alpha,alpha-trehalose]' '9.A.76.1.1|[unsaturatedfattyacid]'
#  '3.A.1.20.2|[hexosephosphate]' '3.A.1.1.38|[inositolphosphate]'
#  '3.A.1.1.43|[alpha,alpha-trehalose,melibiose]'
#  '2.A.40.3.3|[7,9-dihydro-1H-purine-2,6,8(3H)-trione,9H-xanthine]'
#  '1.A.29.1.1|[amide]'
#  '3.A.1.2.5|[fucose,xylose,arabinose,glucose,galactose]'
#  '3.A.1.2.29|[keto-D-fructose]' '3.A.1.2.6|[allose]'
#  '3.A.1.17.11|[riboflavin]']
# blast_phytohormones
# [nan 'Auxin-TAM' 'Auxin-Ipyr;Auxin-TAM' 'Auxin-IAM;Auxin-IAN' 'Auxin-Ipyr'
#  'Auxin-IAN' 'Auxin-IAM']
# blast_vibrioferrin
# [nan 'pvuABCDE']
# blast_DMSP
# [nan 'DMSP_cleavage' 'DMSP_demethylation']
# dbCAN_CAZy
# [nan 'laminarin' 'chitin' 'NAG-cont. substrate'
#  'galactose-rich substrate & carrageenan' 'GalNAc ' 'α-1,4-glucan'
#  'trehalose' 'α-1,4-glucan|trehalose' 'pectin-like substrate'
#  'rhamnose-containing substr.|pectin-like substrate' 'alginate'
#  'sialic acid oligosaccharides' 'fructose' 'digeneaside'
#  'arabinose-rich substrate']
# Species
# ['Sulfitobacter pseudonitzschiae strain SMR1'
#  'Phaeobacter gallaeciensis DSM 26640' 'Marinobacter adhaerens HP15'
#  'Ruegeria pomeroyi DSS-3' 'Alteromonas macleodii HOT1A3'
#  'Pseudoalteromonas haloplanktis TAC125' 'Roseovrius HOT5_C3'
#  'Marinovum HOT5_F3']

# %%
df.groupby('filename').size()
# Out:
# filename
# 1402135.12    5190
# 1423144.3     4566
# 225937.3      4541
# 246200.7      4575
# 28108.53      4366
# 326442.8      3647
# C03           4423
# F03           5810
# dtype: int64

# %%
import tarfile
import json

tar_file_name = "brenda_2024_1.json.tar.gz"
data_file_name = "brenda_2024_1.json"
with tarfile.open(os.path.join(dpath,tar_file_name), "r:gz") as tar:
    with tar.extractfile(data_file_name) as f:
        j = json.loads(f.read())

# %%
j['data']['1.1.1.350'].keys()
# Out:
# dict_keys(['id', 'protein', 'recommended_name', 'systematic_name', 'synonyms', 'reaction', 'natural_substrates_products', 'substrates_products', 'turnover_number', 'km_value', 'cofactor', 'subunits', 'protein_variants', 'cloned', 'crystallization', 'purification', 'reference', 'kcat_km_value'])

# %%
cols=['id', 'protein', 'recommended_name', 'systematic_name', 'synonyms']
for i in cols:
    print(i)
    print(j['data']['1.1.1.350'][i])
# Out:
# id
# 1.1.1.350
# protein
# {'1': {'id': '1', 'organism': 'Escherichia coli', 'references': ['1'], 'comment': ''}, '2': {'id': '2', 'organism': 'Escherichia coli', 'source': 'uniprot', 'accessions': ['P77555'], 'references': ['2'], 'comment': ''}}
# recommended_name
# ureidoglycolate dehydrogenase (NAD+)
# systematic_name
# (S)-ureidoglycolate:NAD+ oxidoreductase
# synonyms
# [{'value': 'ureidoglycolate dehydrogenase', 'proteins': ['1'], 'references': ['1'], 'comment': ''}, {'proteins': ['1'], 'references': ['1'], 'comment': 'gene name', 'value': 'AllD'}, {'value': 'AllD', 'proteins': ['2'], 'references': ['2'], 'comment': ''}, {'value': '(S)-ureidoglycolate dehydrogenase', 'proteins': ['2'], 'references': ['2'], 'comment': ''}]

# %%
def get_synonyms(x):
    if 'synonyms' in x:
        names =  [x.get('recommended_name', np.NaN), x.get('systematic_name', np.NaN),]
        
        return ';'.join({i['value'] for i in x['synonyms'] if i['value'] not in names})
    return np.NaN
get_synonyms (j['data']['1.1.1.350'])
# Out:
# '(S)-ureidoglycolate dehydrogenase;AllD;ureidoglycolate dehydrogenase'

# %%
brenda_db = pd.DataFrame([{
    'eC_number': i.get('id', np.NaN),
    'recommended_name' : i.get('recommended_name', np.NaN),
    'systematic_name' : i.get('systematic_name', np.NaN),
    'synonyms' : get_synonyms(i), 
} for i in j['data'].values()])

# %%
brenda_db
# Out:
#         eC_number                            recommended_name  \
# 0     spontaneous                        spontaneous reaction
# 1         1.1.1.1                       alcohol dehydrogenase
# 2        1.1.1.10                        L-xylulose reductase
# 3       1.1.1.100  3-oxoacyl-[acyl-carrier-protein] reductase
# 4       1.1.1.101           acylglycerone-phosphate reductase
# ...           ...                                         ...
# 7870      7.6.2.5                   ABC-type heme transporter
# 7871      7.6.2.6                ABC-type guanine transporter
# 7872      7.6.2.7                ABC-type taurine transporter
# 7873      7.6.2.8            ABC-type vitamin B12 transporter
# 7874      7.6.2.9       ABC-type quaternary amine transporter
#
#                                         systematic_name  \
# 0                    spontaneous non-enzymatic reaction
# 1                           alcohol:NAD+ oxidoreductase
# 2     xylitol:NADP+ 4-oxidoreductase (L-xylulose-for...
# 3     (3R)-3-hydroxyacyl-[acyl-carrier protein]:NADP...
# 4     1-palmitoylglycerol-3-phosphate:NADP+ oxidored...
# ...                                                 ...
# 7870    ATP phosphohydrolase (ABC-type, heme-exporting)
# 7871  ATP phosphohydrolase (ABC-type, guanine-import...
# 7872  ATP phosphohydrolase (ABC-type, taurine-import...
# 7873  ATP phosphohydrolase (ABC-type, vitamin B12-im...
# 7874  ATP phosphohydrolase (ABC-type, quaternary-ami...
#
#                                                synonyms
# 0                                                   NaN
# 1     ADH3;glutathione-dependent formaldehyde dehydr...
# 2     dicarbonyl/L-xylulose reductase;XR;xylitol deh...
# 3     OAR1;XCC0416;3-oxoacyl-[ACP]reductase;MSMEG_67...
# 4     reductase, palmitoyl dihydroxyacetone phosphat...
# ...                                                 ...
# 7870  heme-transporting ATPase;HmuU;HmuTUV;EC 3.6.3....
# 7871            guanine-transporting ATPase;EC 3.6.3.37
# 7872            taurine-transporting ATPase;EC 3.6.3.36
# 7873  cobalamin-specific ECF-type ABC transporter;Bt...
# 7874  EC 3.6.3.32;BccT1;OpuC;N288_21505;glycine beta...
#
# [7875 rows x 4 columns]

# %%
df = pd.merge(df, brenda_db, on='eC_number', how='left')

# %%
df
# Out:
#          filename       locus_tag type  start    end strand  gene  \
# 0      1402135.12  ALGBIFEJ_00001  CDS      7    408      +   NaN
# 1      1402135.12  ALGBIFEJ_00002  CDS    405    806      +   NaN
# 2      1402135.12  ALGBIFEJ_00003  CDS    803   1381      +   NaN
# 3      1402135.12  ALGBIFEJ_00004  CDS   1378   2424      +   NaN
# 4      1402135.12  ALGBIFEJ_00005  CDS   2501   4750      +  fadE
# ...           ...             ...  ...    ...    ...    ...   ...
# 37113         F03  FLOFJFJI_05677  CDS  96160  96888      -   NaN
# 37114         F03  FLOFJFJI_05678  CDS  97013  97315      -   NaN
# 37115         F03  FLOFJFJI_05679  CDS  97416  97826      -   NaN
# 37116         F03  FLOFJFJI_05680  CDS  97879  98265      -   NaN
# 37117         F03  FLOFJFJI_05681  CDS  98387  98743      -   NaN
#
#                              product      db_xref eC_number  ... antiSMASH  \
# 0               hypothetical protein          NaN       NaN  ...       NaN
# 1               hypothetical protein          NaN       NaN  ...       NaN
# 2               hypothetical protein          NaN       NaN  ...       NaN
# 3               hypothetical protein          NaN       NaN  ...       NaN
# 4      Acyl-coenzyme A dehydrogenase  COG:COG1960   1.3.8.7  ...       NaN
# ...                              ...          ...       ...  ...       ...
# 37113           hypothetical protein          NaN       NaN  ...       NaN
# 37114           hypothetical protein          NaN       NaN  ...       NaN
# 37115           hypothetical protein          NaN       NaN  ...       NaN
# 37116           hypothetical protein          NaN       NaN  ...       NaN
# 37117           hypothetical protein          NaN       NaN  ...       NaN
#
#       BioV_transp blast_phytohormones blast_vibrioferrin blast_DMSP  \
# 0             NaN                 NaN                NaN        NaN
# 1             NaN                 NaN                NaN        NaN
# 2             NaN                 NaN                NaN        NaN
# 3             NaN                 NaN                NaN        NaN
# 4             NaN                 NaN                NaN        NaN
# ...           ...                 ...                ...        ...
# 37113         NaN                 NaN                NaN        NaN
# 37114         NaN                 NaN                NaN        NaN
# 37115         NaN                 NaN                NaN        NaN
# 37116         NaN                 NaN                NaN        NaN
# 37117         NaN                 NaN                NaN        NaN
#
#       dbCAN_CAZy                                     Species  \
# 0            NaN  Sulfitobacter pseudonitzschiae strain SMR1
# 1            NaN  Sulfitobacter pseudonitzschiae strain SMR1
# 2            NaN  Sulfitobacter pseudonitzschiae strain SMR1
# 3            NaN  Sulfitobacter pseudonitzschiae strain SMR1
# 4            NaN  Sulfitobacter pseudonitzschiae strain SMR1
# ...          ...                                         ...
# 37113        NaN                           Marinovum HOT5_F3
# 37114        NaN                           Marinovum HOT5_F3
# 37115        NaN                           Marinovum HOT5_F3
# 37116        NaN                           Marinovum HOT5_F3
# 37117        NaN                           Marinovum HOT5_F3
#
#                           recommended_name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4      medium-chain acyl-CoA dehydrogenase
# ...                                    ...
# 37113                                  NaN
# 37114                                  NaN
# 37115                                  NaN
# 37116                                  NaN
# 37117                                  NaN
#
#                                          systematic_name  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      medium-chain acyl-CoA:electron-transfer flavop...
# ...                                                  ...
# 37113                                                NaN
# 37114                                                NaN
# 37115                                                NaN
# 37116                                                NaN
# 37117                                                NaN
#
#                                                 synonyms
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      LCAD;EC 1.3.2.2;acyl dehydrogenase;ACAD-9;EC 1...
# ...                                                  ...
# 37113                                                NaN
# 37114                                                NaN
# 37115                                                NaN
# 37116                                                NaN
# 37117                                                NaN
#
# [37118 rows x 23 columns]

# %%
df.loc[~df.eC_number.isna() & df.recommended_name.isna(), ['eC_number', 'KO']].value_counts(dropna=False)
# Out:
# eC_number  KO
# 1.-.-.-    NaN       84
# 2.7.-.-    NaN       51
# 3.4.-.-    NaN       39
# 3.5.1.-    NaN       38
# 1.3.99.-   NaN       38
#                      ..
# 3.4.13.-   K01270     1
# 1.18.1.-   K26139     1
# 3.4.14.-   K01354     1
# 3.4.21.-   K03503     1
# 1.-.-.-    K00004     1
# Name: count, Length: 474, dtype: int64

# %%
df.isna().sum()
# Out:
# filename                   0
# locus_tag                  0
# type                       0
# start                      0
# end                        0
# strand                     0
# gene                   18216
# product                    0
# db_xref                23277
# eC_number              24839
# KO                     16720
# KEGG_KM                33069
# KEGG_manual            37102
# antiSMASH              35867
# BioV_transp            34195
# blast_phytohormones    35913
# blast_vibrioferrin     36915
# blast_DMSP             37003
# dbCAN_CAZy             37063
# Species                    0
# recommended_name       26976
# systematic_name        27540
# synonyms               27211
# dtype: int64

# %%
kegg_df = pd.read_csv(os.path.join(dpath,'kegg_pathways.csv'))
kegg_df
# Out:
#        Unnamed: 0                                    main  \
# 0               0                        09100 Metabolism
# 1               1                        09100 Metabolism
# 2               2                        09100 Metabolism
# 3               3                        09100 Metabolism
# 4               4                        09100 Metabolism
# ...           ...                                     ...
# 58187       58188  09190 Not Included in Pathway or Brite
# 58188       58189  09190 Not Included in Pathway or Brite
# 58189       58190  09190 Not Included in Pathway or Brite
# 58190       58191  09190 Not Included in Pathway or Brite
# 58191       58192  09190 Not Included in Pathway or Brite
#
#                                  sub  \
# 0      09101 Carbohydrate metabolism
# 1      09101 Carbohydrate metabolism
# 2      09101 Carbohydrate metabolism
# 3      09101 Carbohydrate metabolism
# 4      09101 Carbohydrate metabolism
# ...                              ...
# 58187     09194 Poorly characterized
# 58188     09194 Poorly characterized
# 58189     09194 Poorly characterized
# 58190     09194 Poorly characterized
# 58191     09194 Poorly characterized
#
#                                                     path  \
# 0      00010 Glycolysis / Gluconeogenesis [PATH:ko00010]
# 1      00010 Glycolysis / Gluconeogenesis [PATH:ko00010]
# 2      00010 Glycolysis / Gluconeogenesis [PATH:ko00010]
# 3      00010 Glycolysis / Gluconeogenesis [PATH:ko00010]
# 4      00010 Glycolysis / Gluconeogenesis [PATH:ko00010]
# ...                                                  ...
# 58187                             99997 Function unknown
# 58188                             99997 Function unknown
# 58189                             99997 Function unknown
# 58190                             99997 Function unknown
# 58191                             99997 Function unknown
#
#                                                   ecpath path_id
# 0                    K00844  HK; hexokinase [EC:2.7.1.1]  K00844
# 1                  K12407  GCK; glucokinase [EC:2.7.1.2]  K12407
# 2                  K00845  glk; glucokinase [EC:2.7.1.2]  K00845
# 3                  K25026  glk; glucokinase [EC:2.7.1.2]  K25026
# 4      K01810  GPI, pgi; glucose-6-phosphate isomeras...  K01810
# ...                                                  ...     ...
# 58187            K07220  K07220; uncharacterized protein  K07220
# 58188            K07276  K07276; uncharacterized protein  K07276
# 58189            K07338  K07338; uncharacterized protein  K07338
# 58190              K07586  ygaC; uncharacterized protein  K07586
# 58191              K07742  ylxR; uncharacterized protein  K07742
#
# [58192 rows x 6 columns]

# %%
kegg_df2 = kegg_df.drop_duplicates(subset=['ecpath','path_id'])

# %%
kegg_df2[['ecpath','path_id']].value_counts()
kegg_df2[['path_id',]].value_counts()
# Out:
# path_id
# K00001     1
# K17447     1
# K17445     1
# K17444     1
# K17443     1
#           ..
# K08860     1
# K08859     1
# K08858     1
# K08857     1
# K86952     1
# Name: count, Length: 25226, dtype: int64

# %%
df2 = pd.merge(df, kegg_df2, left_on='KO', right_on='path_id', how='left')

# %%
df2
# Out:
#          filename       locus_tag type  start    end strand  gene  \
# 0      1402135.12  ALGBIFEJ_00001  CDS      7    408      +   NaN
# 1      1402135.12  ALGBIFEJ_00002  CDS    405    806      +   NaN
# 2      1402135.12  ALGBIFEJ_00003  CDS    803   1381      +   NaN
# 3      1402135.12  ALGBIFEJ_00004  CDS   1378   2424      +   NaN
# 4      1402135.12  ALGBIFEJ_00005  CDS   2501   4750      +  fadE
# ...           ...             ...  ...    ...    ...    ...   ...
# 37113         F03  FLOFJFJI_05677  CDS  96160  96888      -   NaN
# 37114         F03  FLOFJFJI_05678  CDS  97013  97315      -   NaN
# 37115         F03  FLOFJFJI_05679  CDS  97416  97826      -   NaN
# 37116         F03  FLOFJFJI_05680  CDS  97879  98265      -   NaN
# 37117         F03  FLOFJFJI_05681  CDS  98387  98743      -   NaN
#
#                              product      db_xref eC_number  ...  \
# 0               hypothetical protein          NaN       NaN  ...
# 1               hypothetical protein          NaN       NaN  ...
# 2               hypothetical protein          NaN       NaN  ...
# 3               hypothetical protein          NaN       NaN  ...
# 4      Acyl-coenzyme A dehydrogenase  COG:COG1960   1.3.8.7  ...
# ...                              ...          ...       ...  ...
# 37113           hypothetical protein          NaN       NaN  ...
# 37114           hypothetical protein          NaN       NaN  ...
# 37115           hypothetical protein          NaN       NaN  ...
# 37116           hypothetical protein          NaN       NaN  ...
# 37117           hypothetical protein          NaN       NaN  ...
#
#                                           Species  \
# 0      Sulfitobacter pseudonitzschiae strain SMR1
# 1      Sulfitobacter pseudonitzschiae strain SMR1
# 2      Sulfitobacter pseudonitzschiae strain SMR1
# 3      Sulfitobacter pseudonitzschiae strain SMR1
# 4      Sulfitobacter pseudonitzschiae strain SMR1
# ...                                           ...
# 37113                           Marinovum HOT5_F3
# 37114                           Marinovum HOT5_F3
# 37115                           Marinovum HOT5_F3
# 37116                           Marinovum HOT5_F3
# 37117                           Marinovum HOT5_F3
#
#                           recommended_name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4      medium-chain acyl-CoA dehydrogenase
# ...                                    ...
# 37113                                  NaN
# 37114                                  NaN
# 37115                                  NaN
# 37116                                  NaN
# 37117                                  NaN
#
#                                          systematic_name  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      medium-chain acyl-CoA:electron-transfer flavop...
# ...                                                  ...
# 37113                                                NaN
# 37114                                                NaN
# 37115                                                NaN
# 37116                                                NaN
# 37117                                                NaN
#
#                                                 synonyms Unnamed: 0  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4      LCAD;EC 1.3.2.2;acyl dehydrogenase;ACAD-9;EC 1...     2324.0
# ...                                                  ...        ...
# 37113                                                NaN        NaN
# 37114                                                NaN        NaN
# 37115                                                NaN        NaN
# 37116                                                NaN        NaN
# 37117                                                NaN        NaN
#
#                    main                     sub  \
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4      09100 Metabolism  09103 Lipid metabolism
# ...                 ...                     ...
# 37113               NaN                     NaN
# 37114               NaN                     NaN
# 37115               NaN                     NaN
# 37116               NaN                     NaN
# 37117               NaN                     NaN
#
#                                               path  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4      00071 Fatty acid degradation [PATH:ko00071]
# ...                                            ...
# 37113                                          NaN
# 37114                                          NaN
# 37115                                          NaN
# 37116                                          NaN
# 37117                                          NaN
#
#                                                   ecpath path_id
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4      K06445  fadE; acyl-CoA dehydrogenase [EC:1.3.9...  K06445
# ...                                                  ...     ...
# 37113                                                NaN     NaN
# 37114                                                NaN     NaN
# 37115                                                NaN     NaN
# 37116                                                NaN     NaN
# 37117                                                NaN     NaN
#
# [37118 rows x 29 columns]

# %%
signal_df = pd.read_csv(os.path.join(dpath, '10cc_signalP.csv'))

# %%
signal_df.rename(columns={'product': 'signal_product', 'Prediction': 'SignalP'}, inplace=True)

# %%
df3 = pd.merge(df2, signal_df, on=['filename', 'locus_tag'], how='left')

# %%
df3
# Out:
#          filename       locus_tag type  start    end strand  gene  \
# 0      1402135.12  ALGBIFEJ_00001  CDS      7    408      +   NaN
# 1      1402135.12  ALGBIFEJ_00002  CDS    405    806      +   NaN
# 2      1402135.12  ALGBIFEJ_00003  CDS    803   1381      +   NaN
# 3      1402135.12  ALGBIFEJ_00004  CDS   1378   2424      +   NaN
# 4      1402135.12  ALGBIFEJ_00005  CDS   2501   4750      +  fadE
# ...           ...             ...  ...    ...    ...    ...   ...
# 37113         F03  FLOFJFJI_05677  CDS  96160  96888      -   NaN
# 37114         F03  FLOFJFJI_05678  CDS  97013  97315      -   NaN
# 37115         F03  FLOFJFJI_05679  CDS  97416  97826      -   NaN
# 37116         F03  FLOFJFJI_05680  CDS  97879  98265      -   NaN
# 37117         F03  FLOFJFJI_05681  CDS  98387  98743      -   NaN
#
#                              product      db_xref eC_number  ...  \
# 0               hypothetical protein          NaN       NaN  ...
# 1               hypothetical protein          NaN       NaN  ...
# 2               hypothetical protein          NaN       NaN  ...
# 3               hypothetical protein          NaN       NaN  ...
# 4      Acyl-coenzyme A dehydrogenase  COG:COG1960   1.3.8.7  ...
# ...                              ...          ...       ...  ...
# 37113           hypothetical protein          NaN       NaN  ...
# 37114           hypothetical protein          NaN       NaN  ...
# 37115           hypothetical protein          NaN       NaN  ...
# 37116           hypothetical protein          NaN       NaN  ...
# 37117           hypothetical protein          NaN       NaN  ...
#
#                                          systematic_name  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      medium-chain acyl-CoA:electron-transfer flavop...
# ...                                                  ...
# 37113                                                NaN
# 37114                                                NaN
# 37115                                                NaN
# 37116                                                NaN
# 37117                                                NaN
#
#                                                 synonyms Unnamed: 0  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4      LCAD;EC 1.3.2.2;acyl dehydrogenase;ACAD-9;EC 1...     2324.0
# ...                                                  ...        ...
# 37113                                                NaN        NaN
# 37114                                                NaN        NaN
# 37115                                                NaN        NaN
# 37116                                                NaN        NaN
# 37117                                                NaN        NaN
#
#                    main                     sub  \
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4      09100 Metabolism  09103 Lipid metabolism
# ...                 ...                     ...
# 37113               NaN                     NaN
# 37114               NaN                     NaN
# 37115               NaN                     NaN
# 37116               NaN                     NaN
# 37117               NaN                     NaN
#
#                                               path  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4      00071 Fatty acid degradation [PATH:ko00071]
# ...                                            ...
# 37113                                          NaN
# 37114                                          NaN
# 37115                                          NaN
# 37116                                          NaN
# 37117                                          NaN
#
#                                                   ecpath path_id  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4      K06445  fadE; acyl-CoA dehydrogenase [EC:1.3.9...  K06445
# ...                                                  ...     ...
# 37113                                                NaN     NaN
# 37114                                                NaN     NaN
# 37115                                                NaN     NaN
# 37116                                                NaN     NaN
# 37117                                                NaN     NaN
#
#                       signal_product SignalP
# 0               hypothetical protein   OTHER
# 1               hypothetical protein   OTHER
# 2               hypothetical protein   OTHER
# 3               hypothetical protein   OTHER
# 4      Acyl-coenzyme A dehydrogenase   OTHER
# ...                              ...     ...
# 37113           hypothetical protein   OTHER
# 37114           hypothetical protein   OTHER
# 37115           hypothetical protein   OTHER
# 37116           hypothetical protein   OTHER
# 37117           hypothetical protein   OTHER
#
# [37118 rows x 31 columns]

# %%
df3.rename(columns={'eC_number': 'EC_number'}, inplace=True)

# %%
df3.to_csv('10cc_ecpath_master.csv', index=False)
